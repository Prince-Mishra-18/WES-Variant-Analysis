# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ✅ Step 1: Create a fresh project folder structure on Google Drive
import os

base_dir = "/content/drive/MyDrive/Cancer_WES_Project"
subdirs = [
    "raw_fastq",
    "reference",
    "bam_files",
    "annotation",
    "vcf_files",
    "results"
]

for sub in subdirs:
    os.makedirs(os.path.join(base_dir, sub), exist_ok=True)

print("✅ Project folder structure created successfully.")
# Out:
# ✅ Project folder structure created successfully.

# %%
# ✅ Install core bioinformatics tools
# !apt-get update -qq
# !apt-get install -y -qq fastqc bwa samtools bcftools bedtools
# !wget -q https://github.com/broadinstitute/gatk/releases/download/4.4.0.0/gatk-4.4.0.0.zip
# !unzip -q gatk-4.4.0.0.zip
# !mv gatk-4.4.0.0 /opt/gatk
# !chmod +x /opt/gatk/gatk
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Extracting templates from packages: 100%
# Selecting previously unselected package libhtscodecs2:amd64.
# (Reading database ... 126281 files and directories currently installed.)
# Preparing to unpack .../00-libhtscodecs2_1.1.1-3_amd64.deb ...
# Unpacking libhtscodecs2:amd64 (1.1.1-3) ...
# Selecting previously unselected package libhts3:amd64.
# Preparing to unpack .../01-libhts3_1.13+ds-2build1_amd64.deb ...
# Unpacking libhts3:amd64 (1.13+ds-2build1) ...
# Selecting previously unselected package bcftools.
# Preparing to unpack .../02-bcftools_1.13-1_amd64.deb ...
# Unpacking bcftools (1.13-1) ...
# Selecting previously unselected package bedtools.
# Preparing to unpack .../03-bedtools_2.30.0+dfsg-2ubuntu0.1_amd64.deb ...
# Unpacking bedtools (2.30.0+dfsg-2ubuntu0.1) ...
# Selecting previously unselected package bwa.
# Preparing to unpack .../04-bwa_0.7.17-6_amd64.deb ...
# Unpacking bwa (0.7.17-6) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../05-default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../06-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../07-openjdk-11-jre_11.0.27+6~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../08-default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package libcommons-math3-java.
# Preparing to unpack .../09-libcommons-math3-java_3.6.1-3_all.deb ...
# Unpacking libcommons-math3-java (3.6.1-3) ...
# Selecting previously unselected package libjbzip2-java.
# Preparing to unpack .../10-libjbzip2-java_0.9.1-7_all.deb ...
# Unpacking libjbzip2-java (0.9.1-7) ...
# Selecting previously unselected package libapache-pom-java.
# Preparing to unpack .../11-libapache-pom-java_18-1_all.deb ...
# Unpacking libapache-pom-java (18-1) ...
# Selecting previously unselected package libcommons-parent-java.
# Preparing to unpack .../12-libcommons-parent-java_43-1_all.deb ...
# Unpacking libcommons-parent-java (43-1) ...
# Selecting previously unselected package libcommons-compress-java.
# Preparing to unpack .../13-libcommons-compress-java_1.21-1_all.deb ...
# Unpacking libcommons-compress-java (1.21-1) ...
# Selecting previously unselected package libcommons-logging-java.
# Preparing to unpack .../14-libcommons-logging-java_1.2-2_all.deb ...
# Unpacking libcommons-logging-java (1.2-2) ...
# Selecting previously unselected package libcommons-jexl2-java.
# Preparing to unpack .../15-libcommons-jexl2-java_2.1.1-5_all.deb ...
# Unpacking libcommons-jexl2-java (2.1.1-5) ...
# Selecting previously unselected package libjson-simple-java.
# Preparing to unpack .../16-libjson-simple-java_2.3.0-1_all.deb ...
# Unpacking libjson-simple-java (2.3.0-1) ...
# Selecting previously unselected package libngs-sdk2:amd64.
# Preparing to unpack .../17-libngs-sdk2_2.11.2-3_amd64.deb ...
# Unpacking libngs-sdk2:amd64 (2.11.2-3) ...
# Selecting previously unselected package libngs-sdk-dev:amd64.
# Preparing to unpack .../18-libngs-sdk-dev_2.11.2-3_amd64.deb ...
# Unpacking libngs-sdk-dev:amd64 (2.11.2-3) ...
# Selecting previously unselected package libngs-java:amd64.
# Preparing to unpack .../19-libngs-java_2.11.2-3_amd64.deb ...
# Unpacking libngs-java:amd64 (2.11.2-3) ...
# Selecting previously unselected package libsnappy-jni.
# Preparing to unpack .../20-libsnappy-jni_1.1.8.3-1_amd64.deb ...
# Unpacking libsnappy-jni (1.1.8.3-1) ...
# Selecting previously unselected package libsnappy-java.
# Preparing to unpack .../21-libsnappy-java_1.1.8.3-1_all.deb ...
# Unpacking libsnappy-java (1.1.8.3-1) ...
# Selecting previously unselected package libhtsjdk-java.
# Preparing to unpack .../22-libhtsjdk-java_2.24.1+dfsg-1_all.deb ...
# Unpacking libhtsjdk-java (2.24.1+dfsg-1) ...
# Selecting previously unselected package libfindbin-libs-perl.
# Preparing to unpack .../23-libfindbin-libs-perl_2.190.02-1_all.deb ...
# Unpacking libfindbin-libs-perl (2.190.02-1) ...
# Selecting previously unselected package libargs4j-java.
# Preparing to unpack .../24-libargs4j-java_2.33-1.1_all.deb ...
# Unpacking libargs4j-java (2.33-1.1) ...
# Selecting previously unselected package libcommons-io-java.
# Preparing to unpack .../25-libcommons-io-java_2.11.0-2_all.deb ...
# Unpacking libcommons-io-java (2.11.0-2) ...
# Selecting previously unselected package libcommons-lang3-java.
# Preparing to unpack .../26-libcommons-lang3-java_3.11-1_all.deb ...
# Unpacking libcommons-lang3-java (3.11-1) ...
# Selecting previously unselected package libsis-base-jni.
# Preparing to unpack .../27-libsis-base-jni_18.09~pre1+git20180928.45fbd31+dfsg-3_amd64.deb ...
# Unpacking libsis-base-jni (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Selecting previously unselected package libsis-base-java.
# Preparing to unpack .../28-libsis-base-java_18.09~pre1+git20180928.45fbd31+dfsg-3_all.deb ...
# Unpacking libsis-base-java (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Selecting previously unselected package libsis-jhdf5-jni.
# Preparing to unpack .../29-libsis-jhdf5-jni_19.04.0+dfsg-4_amd64.deb ...
# Unpacking libsis-jhdf5-jni (19.04.0+dfsg-4) ...
# Selecting previously unselected package libsis-jhdf5-java.
# Preparing to unpack .../30-libsis-jhdf5-java_19.04.0+dfsg-4_all.deb ...
# Unpacking libsis-jhdf5-java (19.04.0+dfsg-4) ...
# Selecting previously unselected package fastqc.
# Preparing to unpack .../31-fastqc_0.11.9+dfsg-5_all.deb ...
# Unpacking fastqc (0.11.9+dfsg-5) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../32-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../33-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../34-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../35-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../36-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../37-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package samtools.
# Preparing to unpack .../38-samtools_1.13-4_amd64.deb ...
# Unpacking samtools (1.13-4) ...
# Setting up libhtscodecs2:amd64 (1.1.1-3) ...
# Setting up libhts3:amd64 (1.13+ds-2build1) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up bwa (0.7.17-6) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up bcftools (1.13-1) ...
# Setting up libngs-sdk2:amd64 (2.11.2-3) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Setting up libfindbin-libs-perl (2.190.02-1) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up libjson-simple-java (2.3.0-1) ...
# Setting up samtools (1.13-4) ...
# Setting up libsis-base-jni (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Setting up libapache-pom-java (18-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libjbzip2-java (0.9.1-7) ...
# Setting up libngs-sdk-dev:amd64 (2.11.2-3) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libcommons-math3-java (3.6.1-3) ...
# Setting up libsis-jhdf5-jni (19.04.0+dfsg-4) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libngs-java:amd64 (2.11.2-3) ...
# Setting up libsnappy-jni (1.1.8.3-1) ...
# Setting up bedtools (2.30.0+dfsg-2ubuntu0.1) ...
# Setting up libargs4j-java (2.33-1.1) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up libcommons-logging-java (1.2-2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Setting up libcommons-jexl2-java (2.1.1-5) ...
# Setting up libcommons-lang3-java (3.11-1) ...
# Setting up libsnappy-java (1.1.8.3-1) ...
# Setting up libcommons-compress-java (1.21-1) ...
# Setting up libcommons-io-java (2.11.0-2) ...
# Setting up libsis-base-java (18.09~pre1+git20180928.45fbd31+dfsg-3) ...
# Setting up libhtsjdk-java (2.24.1+dfsg-1) ...
# Setting up libsis-jhdf5-java (19.04.0+dfsg-4) ...
# Setting up fastqc (0.11.9+dfsg-5) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link

# %%
# !fastqc --version
# !bwa 2>&1 | head -n 1
# !samtools --version | head -n 1
# !/opt/gatk/gatk --version
# !bcftools --version | head -n 1
# Out:
# FastQC v0.11.9
#
# samtools 1.13
# Using GATK jar /opt/gatk/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /opt/gatk/gatk-package-4.4.0.0-local.jar --version
# Error: LinkageError occurred while loading main class org.broadinstitute.hellbender.Main
# 	java.lang.UnsupportedClassVersionError: org/broadinstitute/hellbender/Main has been compiled by a more recent version of the Java Runtime (class file version 61.0), this version of the Java Runtime only recognizes class file versions up to 55.0
# bcftools 1.13

# %%
# Remove older Java versions if needed
# !sudo apt-get remove openjdk-11-jre-headless -y
# !sudo apt-get update

# Install Java 17
# !sudo apt install openjdk-17-jre-headless -y

# Verify version
# !java -version
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   fonts-dejavu-extra java-common libapache-pom-java libargs4j-java
#   libatk-wrapper-java libatk-wrapper-java-jni libcommons-compress-java
#   libcommons-io-java libcommons-jexl2-java libcommons-lang3-java
#   libcommons-logging-java libcommons-math3-java libcommons-parent-java
#   libfindbin-libs-perl libhtsjdk-java libjbzip2-java libjson-simple-java
#   libngs-java libngs-sdk-dev libngs-sdk2 libpcsclite1 libsis-base-java
#   libsis-base-jni libsis-jhdf5-java libsis-jhdf5-jni libsnappy-java
#   libsnappy-jni
# Use 'sudo apt autoremove' to remove them.
# The following packages will be REMOVED:
#   ca-certificates-java default-jre default-jre-headless fastqc
#   openjdk-11-jdk-headless openjdk-11-jre openjdk-11-jre-headless
# 0 upgraded, 0 newly installed, 7 to remove and 36 not upgraded.
# After this operation, 259 MB disk space will be freed.
# (Reading database ... 127094 files and directories currently installed.)
# Removing fastqc (0.11.9+dfsg-5) ...
# Removing default-jre (2:1.11-72build2) ...
# Removing openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Removing openjdk-11-jdk-headless:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Removing default-jre-headless (2:1.11-72build2) ...
# Removing openjdk-11-jre-headless:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Removing ca-certificates-java (20190909ubuntu1.2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for ca-certificates (20240203~22.04.1) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
#
# updates of cacerts keystore disabled.
# done.
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   fonts-dejavu-extra libapache-pom-java libargs4j-java libatk-wrapper-java
#   libatk-wrapper-java-jni libcommons-compress-java libcommons-io-java
#   libcommons-jexl2-java libcommons-lang3-java libcommons-logging-java
#   libcommons-math3-java libcommons-parent-java libfindbin-libs-perl
#   libhtsjdk-java libjbzip2-java libjson-simple-java libngs-java libngs-sdk-dev
#   libngs-sdk2 libsis-base-java libsis-base-jni libsis-jhdf5-java
#   libsis-jhdf5-jni libsnappy-java libsnappy-jni
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   ca-certificates-java
# Suggested packages:
#   libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   ca-certificates-java openjdk-17-jre-headless
# 0 upgraded, 2 newly installed, 0 to remove and 36 not upgraded.
# Need to get 48.3 MB of archives.
# After this operation, 193 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jre-headless amd64 17.0.15+6~us1-0ubuntu1~22.04 [48.3 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ca-certificates-java all 20190909ubuntu1.2 [12.1 kB]
# Fetched 48.3 MB in 1s (61.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package openjdk-17-jre-headless:amd64.
# (Reading database ... 126562 files and directories currently installed.)
# Preparing to unpack .../openjdk-17-jre-headless_17.0.15+6~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-17-jre-headless:amd64 (17.0.15+6~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package ca-certificates-java.
# Preparing to unpack .../ca-certificates-java_20190909ubuntu1.2_all.deb ...
# Unpacking ca-certificates-java (20190909ubuntu1.2) ...
# Setting up openjdk-17-jre-headless:amd64 (17.0.15+6~us1-0ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/java to provide /usr/bin/java (java) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jpackage to provide /usr/bin/jpackage (jpackage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/keytool to provide /usr/bin/keytool (keytool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/rmiregistry to provide /usr/bin/rmiregistry (rmiregistry) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/lib/jexec to provide /usr/bin/jexec (jexec) in auto mode
# Setting up ca-certificates-java (20190909ubuntu1.2) ...
# Processing triggers for ca-certificates (20240203~22.04.1) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
#
# done.
# done.
# openjdk version "17.0.15" 2025-04-15
# OpenJDK Runtime Environment (build 17.0.15+6-Ubuntu-0ubuntu122.04)
# OpenJDK 64-Bit Server VM (build 17.0.15+6-Ubuntu-0ubuntu122.04, mixed mode, sharing)

# %%
# !/opt/gatk/gatk --version
# Out:
# Using GATK jar /opt/gatk/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /opt/gatk/gatk-package-4.4.0.0-local.jar --version
# The Genome Analysis Toolkit (GATK) v4.4.0.0
# HTSJDK Version: 3.0.5
# Picard Version: 3.0.0

# %%
# ✅ Install SRA Toolkit
# !apt-get install -y sra-toolkit

# ✅ Confirm installation
# !which prefetch
# !which fasterq-dump
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   fonts-dejavu-extra libapache-pom-java libargs4j-java libatk-wrapper-java
#   libatk-wrapper-java-jni libcommons-compress-java libcommons-io-java
#   libcommons-jexl2-java libcommons-lang3-java libcommons-logging-java
#   libcommons-math3-java libcommons-parent-java libfindbin-libs-perl
#   libhtsjdk-java libjbzip2-java libjson-simple-java libngs-java libngs-sdk-dev
#   libngs-sdk2 libsis-base-java libsis-base-jni libsis-jhdf5-java
#   libsis-jhdf5-jni libsnappy-java libsnappy-jni
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
# Suggested packages:
#   blends-doc menu-l10n gksu | kde-runtime | ktsuss
# The following NEW packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
#   sra-toolkit
# 0 upgraded, 7 newly installed, 0 to remove and 36 not upgraded.
# Need to get 8,290 kB of archives.
# After this operation, 23.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 menu amd64 2.1.47ubuntu4 [354 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 blends-common all 0.7.4ubuntu1 [15.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkdf5-2 amd64 2.11.2+dfsg-4build2 [14.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libncbi-vdb2 amd64 2.11.2+dfsg-4build2 [1,364 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libncbi-wvdb2 amd64 2.11.2+dfsg-4build2 [1,252 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 sra-toolkit amd64 2.11.3+dfsg-1ubuntu1 [5,277 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 med-config all 3.7.1 [11.6 kB]
# Fetched 8,290 kB in 1s (6,297 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package menu.
# (Reading database ... 126887 files and directories currently installed.)
# Preparing to unpack .../0-menu_2.1.47ubuntu4_amd64.deb ...
# Unpacking menu (2.1.47ubuntu4) ...
# Selecting previously unselected package blends-common.
# Preparing to unpack .../1-blends-common_0.7.4ubuntu1_all.deb ...
# Unpacking blends-common (0.7.4ubuntu1) ...
# Selecting previously unselected package libkdf5-2.
# Preparing to unpack .../2-libkdf5-2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libkdf5-2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package libncbi-vdb2.
# Preparing to unpack .../3-libncbi-vdb2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libncbi-vdb2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package libncbi-wvdb2.
# Preparing to unpack .../4-libncbi-wvdb2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libncbi-wvdb2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package sra-toolkit.
# Preparing to unpack .../5-sra-toolkit_2.11.3+dfsg-1ubuntu1_amd64.deb ...
# Unpacking sra-toolkit (2.11.3+dfsg-1ubuntu1) ...
# Selecting previously unselected package med-config.
# Preparing to unpack .../6-med-config_3.7.1_all.deb ...
# Unpacking med-config (3.7.1) ...
# Setting up libncbi-vdb2 (2.11.2+dfsg-4build2) ...
# Setting up libkdf5-2 (2.11.2+dfsg-4build2) ...
# Setting up libncbi-wvdb2 (2.11.2+dfsg-4build2) ...
# Setting up menu (2.1.47ubuntu4) ...
# Setting up blends-common (0.7.4ubuntu1) ...
# Setting up sra-toolkit (2.11.3+dfsg-1ubuntu1) ...
# Setting up med-config (3.7.1) ...
# Adding group `med' (GID 107) ...
# Done.
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# Processing triggers for menu (2.1.47ubuntu4) ...
# /usr/bin/prefetch
# /usr/bin/fasterq-dump

# %%
# ✅ Step: Go to the FASTQ folder
# %cd /content/drive/MyDrive/Cancer_WES_Project/raw_fastq

# ✅ Step: Extract FASTQ with 4 threads
# !fasterq-dump SRR1952986 -e 4

# ✅ Step: Compress the FASTQ files
# !gzip SRR1952986_1.fastq
# !gzip SRR1952986_2.fastq
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/raw_fastq
# spots read      : 12,000,000
# reads read      : 24,000,000
# reads written   : 24,000,000

# %%
# ✅ Reinstall FastQC
# !apt-get update -qq
# !apt-get install -y fastqc
# !fastqc --version
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jre default-jre-headless openjdk-11-jre openjdk-11-jre-headless
# Suggested packages:
#   libnss-mdns fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   default-jre default-jre-headless fastqc openjdk-11-jre
#   openjdk-11-jre-headless
# 0 upgraded, 5 newly installed, 0 to remove and 36 not upgraded.
# Need to get 43.1 MB of archives.
# After this operation, 177 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre-headless amd64 11.0.27+6~us1-0ubuntu1~22.04 [42.6 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.27+6~us1-0ubuntu1~22.04 [214 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre amd64 2:1.11-72build2 [896 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fastqc all 0.11.9+dfsg-5 [370 kB]
# Fetched 43.1 MB in 2s (20.8 MB/s)
# Selecting previously unselected package openjdk-11-jre-headless:amd64.
# (Reading database ... 127237 files and directories currently installed.)
# Preparing to unpack .../openjdk-11-jre-headless_11.0.27+6~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package default-jre-headless.
# Preparing to unpack .../default-jre-headless_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre-headless (2:1.11-72build2) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../openjdk-11-jre_11.0.27+6~us1-0ubuntu1~22.04_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Selecting previously unselected package default-jre.
# Preparing to unpack .../default-jre_2%3a1.11-72build2_amd64.deb ...
# Unpacking default-jre (2:1.11-72build2) ...
# Selecting previously unselected package fastqc.
# Preparing to unpack .../fastqc_0.11.9+dfsg-5_all.deb ...
# Unpacking fastqc (0.11.9+dfsg-5) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jjs to provide /usr/bin/jjs (jjs) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/rmid to provide /usr/bin/rmid (rmid) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/pack200 to provide /usr/bin/pack200 (pack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/unpack200 to provide /usr/bin/unpack200 (unpack200) in auto mode
# Setting up openjdk-11-jre:amd64 (11.0.27+6~us1-0ubuntu1~22.04) ...
# Setting up default-jre-headless (2:1.11-72build2) ...
# Setting up default-jre (2:1.11-72build2) ...
# Setting up fastqc (0.11.9+dfsg-5) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for man-db (2.10.2-1) ...
# FastQC v0.11.9

# %%
# ✅ Move into the FASTQ folder
# %cd /content/drive/MyDrive/Cancer_WES_Project/raw_fastq

# ✅ Run FastQC on both files
# !fastqc SRR1952986_1.fastq.gz SRR1952986_2.fastq.gz
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/raw_fastq
# Started analysis of SRR1952986_1.fastq.gz
# Approx 5% complete for SRR1952986_1.fastq.gz
# Approx 10% complete for SRR1952986_1.fastq.gz
# Approx 15% complete for SRR1952986_1.fastq.gz
# Approx 20% complete for SRR1952986_1.fastq.gz
# Approx 25% complete for SRR1952986_1.fastq.gz
# Approx 30% complete for SRR1952986_1.fastq.gz
# Approx 35% complete for SRR1952986_1.fastq.gz
# Approx 40% complete for SRR1952986_1.fastq.gz
# Approx 45% complete for SRR1952986_1.fastq.gz
# Approx 50% complete for SRR1952986_1.fastq.gz
# Approx 55% complete for SRR1952986_1.fastq.gz
# Approx 60% complete for SRR1952986_1.fastq.gz
# Approx 65% complete for SRR1952986_1.fastq.gz
# Approx 70% complete for SRR1952986_1.fastq.gz
# Approx 75% complete for SRR1952986_1.fastq.gz
# Approx 80% complete for SRR1952986_1.fastq.gz
# Approx 85% complete for SRR1952986_1.fastq.gz
# Approx 90% complete for SRR1952986_1.fastq.gz
# Approx 95% complete for SRR1952986_1.fastq.gz
# Approx 100% complete for SRR1952986_1.fastq.gz
# Analysis complete for SRR1952986_1.fastq.gz
# Started analysis of SRR1952986_2.fastq.gz
# Approx 5% complete for SRR1952986_2.fastq.gz
# Approx 10% complete for SRR1952986_2.fastq.gz
# Approx 15% complete for SRR1952986_2.fastq.gz
# Approx 20% complete for SRR1952986_2.fastq.gz
# Approx 25% complete for SRR1952986_2.fastq.gz
# Approx 30% complete for SRR1952986_2.fastq.gz
# Approx 35% complete for SRR1952986_2.fastq.gz
# Approx 40% complete for SRR1952986_2.fastq.gz
# Approx 45% complete for SRR1952986_2.fastq.gz
# Approx 50% complete for SRR1952986_2.fastq.gz
# Approx 55% complete for SRR1952986_2.fastq.gz
# Approx 60% complete for SRR1952986_2.fastq.gz
# Approx 65% complete for SRR1952986_2.fastq.gz
# Approx 70% complete for SRR1952986_2.fastq.gz
# Approx 75% complete for SRR1952986_2.fastq.gz
# Approx 80% complete for SRR1952986_2.fastq.gz
# Approx 85% complete for SRR1952986_2.fastq.gz
# Approx 90% complete for SRR1952986_2.fastq.gz
# Approx 95% complete for SRR1952986_2.fastq.gz
# Approx 100% complete for SRR1952986_2.fastq.gz
# Analysis complete for SRR1952986_2.fastq.gz

# %%
from google.colab import files

# Download both reports
files.download("/content/drive/MyDrive/Cancer_WES_Project/raw_fastq/SRR1952986_1_fastqc.html")
files.download("/content/drive/MyDrive/Cancer_WES_Project/raw_fastq/SRR1952986_2_fastqc.html")

# %%
# Step 0: Delete old corrupted files (if any)
# !rm -f /content/reference/GRCh38_no_alt_plus_decoy.fa*
# !mkdir -p /content/reference
# %cd /content/reference

# Step 1: Redownload cleanly (~834 MB compressed)
# !wget -O GRCh38_no_alt_plus_decoy.fa.gz "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.40_GRCh38.p14/GRCh38_major_release_seqs_for_alignment_pipelines/GCA_000001405.15_GRCh38_no_alt_plus_hs38d1_analysis_set.fna.gz"

# Step 2: Decompress (~10–11 GB uncompressed)
# !gunzip -f GRCh38_no_alt_plus_decoy.fa.gz

# Step 3: Confirm proper decompressed size
# !ls -lh /content/reference/GRCh38_no_alt_plus_decoy.fa
# Out:
# /content/reference
# --2025-07-18 08:00:57--  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.40_GRCh38.p14/GRCh38_major_release_seqs_for_alignment_pipelines/GCA_000001405.15_GRCh38_no_alt_plus_hs38d1_analysis_set.fna.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.13, 130.14.250.31, 130.14.250.7, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 874637925 (834M) [application/x-gzip]
# Saving to: ‘GRCh38_no_alt_plus_decoy.fa.gz’
#
# GRCh38_no_alt_plus_ 100%[===================>] 834.12M  35.9MB/s    in 22s
#
# 2025-07-18 08:01:19 (37.9 MB/s) - ‘GRCh38_no_alt_plus_decoy.fa.gz’ saved [874637925/874637925]
#
# -rw-r--r-- 1 root root 3.0G Feb 17  2016 /content/reference/GRCh38_no_alt_plus_decoy.fa

# %%
# Count number of lines
# !wc -l /content/reference/GRCh38_no_alt_plus_decoy.fa

# Show how many sequences (chromosomes/contigs) are in the file
# !grep "^>" /content/reference/GRCh38_no_alt_plus_decoy.fa | wc -l

# Print the first 10 sequence headers
# !grep "^>" /content/reference/GRCh38_no_alt_plus_decoy.fa | head -10
# Out:
# 44371205 /content/reference/GRCh38_no_alt_plus_decoy.fa
# 2580
# >chr1  AC:CM000663.2  gi:568336023  LN:248956422  rl:Chromosome  M5:6aef897c3d6ff0c78aff06ac189178dd  AS:GRCh38
# >chr2  AC:CM000664.2  gi:568336022  LN:242193529  rl:Chromosome  M5:f98db672eb0993dcfdabafe2a882905c  AS:GRCh38
# >chr3  AC:CM000665.2  gi:568336021  LN:198295559  rl:Chromosome  M5:76635a41ea913a405ded820447d067b0  AS:GRCh38
# >chr4  AC:CM000666.2  gi:568336020  LN:190214555  rl:Chromosome  M5:3210fecf1eb92d5489da4346b3fddc6e  AS:GRCh38
# >chr5  AC:CM000667.2  gi:568336019  LN:181538259  rl:Chromosome  M5:a811b3dc9fe66af729dc0dddf7fa4f13  AS:GRCh38  hm:47309185-49591369
# >chr6  AC:CM000668.2  gi:568336018  LN:170805979  rl:Chromosome  M5:5691468a67c7e7a7b5f2a3a683792c29  AS:GRCh38
# >chr7  AC:CM000669.2  gi:568336017  LN:159345973  rl:Chromosome  M5:cc044cc2256a1141212660fb07b6171e  AS:GRCh38
# >chr8  AC:CM000670.2  gi:568336016  LN:145138636  rl:Chromosome  M5:c67955b5f7815a9a1edfaa15893d3616  AS:GRCh38
# >chr9  AC:CM000671.2  gi:568336015  LN:138394717  rl:Chromosome  M5:6c198acf68b5af7b9d676dfdd531b5de  AS:GRCh38
# >chr10  AC:CM000672.2  gi:568336014  LN:133797422  rl:Chromosome  M5:c0eeee7acfdaf31b770a509bdaa6e51a  AS:GRCh38

# %%
# ✅ Move to reference folder (just in case)
# %cd /content/reference

# ✅ Create FASTA index
# !samtools faidx GRCh38_no_alt_plus_decoy.fa

# ✅ Create BWA index
# !bwa index GRCh38_no_alt_plus_decoy.fa
# Out:
# /content/reference
# [bwa_index] Pack FASTA... 26.17 sec
# [bwa_index] Construct BWT for the packed sequence...
# [BWTIncCreate] textLength=6211430126, availableWord=449059136
# [BWTIncConstructFromPacked] 10 iterations done. 99999998 characters processed.
# [BWTIncConstructFromPacked] 20 iterations done. 199999998 characters processed.
# [BWTIncConstructFromPacked] 30 iterations done. 299999998 characters processed.
# [BWTIncConstructFromPacked] 40 iterations done. 399999998 characters processed.
# [BWTIncConstructFromPacked] 50 iterations done. 499999998 characters processed.
# [BWTIncConstructFromPacked] 60 iterations done. 599999998 characters processed.
# [BWTIncConstructFromPacked] 70 iterations done. 699999998 characters processed.
# [BWTIncConstructFromPacked] 80 iterations done. 799999998 characters processed.
# [BWTIncConstructFromPacked] 90 iterations done. 899999998 characters processed.
# [BWTIncConstructFromPacked] 100 iterations done. 999999998 characters processed.
# [BWTIncConstructFromPacked] 110 iterations done. 1099999998 characters processed.
# [BWTIncConstructFromPacked] 120 iterations done. 1199999998 characters processed.
# [BWTIncConstructFromPacked] 130 iterations done. 1299999998 characters processed.
# [BWTIncConstructFromPacked] 140 iterations done. 1399999998 characters processed.
# [BWTIncConstructFromPacked] 150 iterations done. 1499999998 characters processed.
# [BWTIncConstructFromPacked] 160 iterations done. 1599999998 characters processed.
# [BWTIncConstructFromPacked] 170 iterations done. 1699999998 characters processed.
# [BWTIncConstructFromPacked] 180 iterations done. 1799999998 characters processed.
# [BWTIncConstructFromPacked] 190 iterations done. 1899999998 characters processed.
# [BWTIncConstructFromPacked] 200 iterations done. 1999999998 characters processed.
# [BWTIncConstructFromPacked] 210 iterations done. 2099999998 characters processed.
# [BWTIncConstructFromPacked] 220 iterations done. 2199999998 characters processed.
# [BWTIncConstructFromPacked] 230 iterations done. 2299999998 characters processed.
# [BWTIncConstructFromPacked] 240 iterations done. 2399999998 characters processed.
# [BWTIncConstructFromPacked] 250 iterations done. 2499999998 characters processed.
# [BWTIncConstructFromPacked] 260 iterations done. 2599999998 characters processed.
# [BWTIncConstructFromPacked] 270 iterations done. 2699999998 characters processed.
# [BWTIncConstructFromPacked] 280 iterations done. 2799999998 characters processed.
# [BWTIncConstructFromPacked] 290 iterations done. 2899999998 characters processed.
# [BWTIncConstructFromPacked] 300 iterations done. 2999999998 characters processed.
# [BWTIncConstructFromPacked] 310 iterations done. 3099999998 characters processed.
# [BWTIncConstructFromPacked] 320 iterations done. 3199999998 characters processed.
# [BWTIncConstructFromPacked] 330 iterations done. 3299999998 characters processed.
# [BWTIncConstructFromPacked] 340 iterations done. 3399999998 characters processed.
# [BWTIncConstructFromPacked] 350 iterations done. 3499999998 characters processed.
# [BWTIncConstructFromPacked] 360 iterations done. 3599999998 characters processed.
# [BWTIncConstructFromPacked] 370 iterations done. 3699999998 characters processed.
# [BWTIncConstructFromPacked] 380 iterations done. 3799999998 characters processed.
# [BWTIncConstructFromPacked] 390 iterations done. 3899999998 characters processed.
# [BWTIncConstructFromPacked] 400 iterations done. 3999999998 characters processed.
# [BWTIncConstructFromPacked] 410 iterations done. 4099999998 characters processed.
# [BWTIncConstructFromPacked] 420 iterations done. 4199999998 characters processed.
# [BWTIncConstructFromPacked] 430 iterations done. 4299999998 characters processed.
# [BWTIncConstructFromPacked] 440 iterations done. 4399999998 characters processed.
# [BWTIncConstructFromPacked] 450 iterations done. 4499999998 characters processed.
# [BWTIncConstructFromPacked] 460 iterations done. 4599999998 characters processed.
# [BWTIncConstructFromPacked] 470 iterations done. 4699999998 characters processed.
# [BWTIncConstructFromPacked] 480 iterations done. 4799999998 characters processed.
# [BWTIncConstructFromPacked] 490 iterations done. 4899999998 characters processed.
# [BWTIncConstructFromPacked] 500 iterations done. 4999999998 characters processed.
# [BWTIncConstructFromPacked] 510 iterations done. 5099999998 characters processed.
# [BWTIncConstructFromPacked] 520 iterations done. 5199999998 characters processed.
# [BWTIncConstructFromPacked] 530 iterations done. 5299999998 characters processed.
# [BWTIncConstructFromPacked] 540 iterations done. 5399999998 characters processed.
# [BWTIncConstructFromPacked] 550 iterations done. 5499999998 characters processed.
# [BWTIncConstructFromPacked] 560 iterations done. 5597672750 characters processed.
# [BWTIncConstructFromPacked] 570 iterations done. 5685172830 characters processed.
# [BWTIncConstructFromPacked] 580 iterations done. 5762939134 characters processed.
# [BWTIncConstructFromPacked] 590 iterations done. 5832054014 characters processed.
# [BWTIncConstructFromPacked] 600 iterations done. 5893479486 characters processed.
# [BWTIncConstructFromPacked] 610 iterations done. 5948070590 characters processed.
# [BWTIncConstructFromPacked] 620 iterations done. 5996587278 characters processed.
# [BWTIncConstructFromPacked] 630 iterations done. 6039704990 characters processed.
# [BWTIncConstructFromPacked] 640 iterations done. 6078024110 characters processed.
# [BWTIncConstructFromPacked] 650 iterations done. 6112078222 characters processed.
# [BWTIncConstructFromPacked] 660 iterations done. 6142341550 characters processed.
# [BWTIncConstructFromPacked] 670 iterations done. 6169235662 characters processed.
# [BWTIncConstructFromPacked] 680 iterations done. 6193135198 characters processed.
# [bwt_gen] Finished constructing BWT in 689 iterations.
# [bwa_index] 4163.30 seconds elapse.
# [bwa_index] Update BWT... 30.59 sec
# [bwa_index] Pack forward-only FASTA... 18.12 sec
# [bwa_index] Construct SA from BWT and Occ... 2216.75 sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa index GRCh38_no_alt_plus_decoy.fa
# [main] Real time: 6641.870 sec; CPU: 6454.931 sec
# /bin/bash: line 1: gatk: command not found

# %%
# ✅ Install GATK (Genome Analysis Toolkit)
# !wget -q https://github.com/broadinstitute/gatk/releases/download/4.4.0.0/gatk-4.4.0.0.zip
# !unzip -q gatk-4.4.0.0.zip
# !mv gatk-4.4.0.0 /opt/gatk
# !ln -s /opt/gatk/gatk /usr/local/bin/gatk
# !gatk --version
# Out:
# Using GATK jar /opt/gatk/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /opt/gatk/gatk-package-4.4.0.0-local.jar --version
# The Genome Analysis Toolkit (GATK) v4.4.0.0
# HTSJDK Version: 3.0.5
# Picard Version: 3.0.0

# %%
# ✅ Create GATK sequence dictionary
# !gatk CreateSequenceDictionary \
   -R GRCh38_no_alt_plus_decoy.fa \
   -O GRCh38_no_alt_plus_decoy.dict
# Out:
# Using GATK jar /opt/gatk/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /opt/gatk/gatk-package-4.4.0.0-local.jar CreateSequenceDictionary -R GRCh38_no_alt_plus_decoy.fa -O GRCh38_no_alt_plus_decoy.dict
# 10:00:20.844 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/opt/gatk/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# [Fri Jul 18 10:00:20 UTC 2025] CreateSequenceDictionary --OUTPUT GRCh38_no_alt_plus_decoy.dict --REFERENCE GRCh38_no_alt_plus_decoy.fa --TRUNCATE_NAMES_AT_WHITESPACE true --NUM_SEQUENCES 2147483647 --VERBOSITY INFO --QUIET false --VALIDATION_STRINGENCY STRICT --COMPRESSION_LEVEL 2 --MAX_RECORDS_IN_RAM 500000 --CREATE_INDEX false --CREATE_MD5_FILE false --help false --version false --showHidden false --USE_JDK_DEFLATER false --USE_JDK_INFLATER false
# [Fri Jul 18 10:00:20 UTC 2025] Executing as root@c319e878d953 on Linux 6.1.123+ amd64; OpenJDK 64-Bit Server VM 17.0.15+6-Ubuntu-0ubuntu122.04; Deflater: Intel; Inflater: Intel; Provider GCS is available; Picard version: Version:4.4.0.0
# [Fri Jul 18 10:00:33 UTC 2025] picard.sam.CreateSequenceDictionary done. Elapsed time: 0.22 minutes.
# Runtime.totalMemory()=878706688
# Tool returned:
# 0

# %%
# ✅ Final, clean alignment to local reference
sample_id = "SRR1952986"

fq1 = f"/content/drive/MyDrive/Cancer_WES_Project/raw_fastq/{sample_id}_1.fastq.gz"
fq2 = f"/content/drive/MyDrive/Cancer_WES_Project/raw_fastq/{sample_id}_2.fastq.gz"
ref = "/content/reference/GRCh38_no_alt_plus_decoy.fa"
bam_dir = "/content/drive/MyDrive/Cancer_WES_Project/bam_files"

raw_bam = f"{bam_dir}/{sample_id}_raw.bam"
sorted_bam = f"{bam_dir}/{sample_id}_sorted.bam"
rg_bam = f"{bam_dir}/{sample_id}_RG.bam"

# !mkdir -p {bam_dir}

# ✅ Step 1: BWA MEM
# !bwa mem -t 2 {ref} {fq1} {fq2} | samtools view -Sb - > {raw_bam}

# ✅ Step 2: Sort
# !samtools sort -o {sorted_bam} {raw_bam}

# ✅ Step 3: Add read groups
# !gatk AddOrReplaceReadGroups \
    -I {sorted_bam} \
    -O {rg_bam} \
    -RGID 1 -RGLB lib1 -RGPL illumina -RGPU unit1 -RGSM {sample_id}

# ✅ Step 4: Index BAM
# !samtools index {rg_bam}

# ✅ Step 5: Check final BAMs
# !ls -lh {bam_dir}
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 132452 sequences (20000252 bp)...
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 28, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (262, 417, 476)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 904)
# [M::mem_pestat] mean and std.dev: (369.61, 145.80)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1118)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 86.822 CPU sec, 56.781 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 24, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (242, 411, 532)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1112)
# [M::mem_pestat] mean and std.dev: (381.71, 141.18)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1402)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 92.287 CPU sec, 59.130 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 21, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (276, 366, 448)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 792)
# [M::mem_pestat] mean and std.dev: (354.33, 106.19)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 964)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 83.106 CPU sec, 53.064 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (1, 28, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (194, 370, 485)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1067)
# [M::mem_pestat] mean and std.dev: (326.82, 163.49)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1358)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 91.074 CPU sec, 58.391 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 29, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (326, 398, 499)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 845)
# [M::mem_pestat] mean and std.dev: (384.24, 150.01)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1018)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 88.368 CPU sec, 60.035 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 19, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (354, 490, 522)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (18, 858)
# [M::mem_pestat] mean and std.dev: (419.16, 138.06)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1026)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 85.079 CPU sec, 54.244 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 21, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (304, 368, 463)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 781)
# [M::mem_pestat] mean and std.dev: (344.67, 148.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 940)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 83.850 CPU sec, 53.673 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 30, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (341, 404, 490)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (43, 788)
# [M::mem_pestat] mean and std.dev: (423.54, 103.42)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 937)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 84.498 CPU sec, 54.598 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 21, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (273, 398, 482)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 900)
# [M::mem_pestat] mean and std.dev: (369.95, 147.47)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 

# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (190, 775)
# [M::mem_pestat] mean and std.dev: (483.25, 83.56)
# [M::mem_pestat] low and high boundaries for proper pairs: (73, 892)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 81.340 CPU sec, 52.635 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 17, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (270, 398, 538)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1074)
# [M::mem_pestat] mean and std.dev: (359.88, 188.88)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1342)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 101.064 CPU sec, 68.889 real sec
# [M::process] read 132452 sequences (20000252 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 33, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (334, 401, 469)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (64, 739)
# [M::mem_pestat] mean and std.dev: (403.57, 97.66)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 874)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 85.286 CPU sec, 56.870 real sec
# [M::process] read 26188 sequences (3954388 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 22, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (233, 420, 492)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1010)
# [M::mem_pestat] mean and std.dev: (356.45, 160.78)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1269)
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 132452 reads in 90.499 CPU sec, 58.170 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 6, 0, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] skip orientation FR as there are not enough pairs
# [M::mem_pestat] skip orientation RF as there are not enough pairs
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_process_seqs] Processed 26188 reads in 11.684 CPU sec, 7.059 real sec
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -t 2 /content/reference/GRCh38_no_alt_plus_decoy.fa /content/drive/MyDrive/Cancer_WES_Project/raw_fastq/SRR1952986_1.fastq.gz /content/drive/MyDrive/Cancer_WES_Project/raw_fastq/SRR1952986_2.fastq.gz
# [main] Real time: 10312.024 sec; CPU: 15898.369 sec
# [bam_sort_core] merging from 10 files and 1 in-memory blocks...
# Using GATK jar /opt/gatk/gatk-package-4.4.0.0-local.jar
# Running:
#     java -Dsamjdk.use_async_io_read_samtools=false -Dsamjdk.use_async_io_write_samtools=true -Dsamjdk.use_async_io_write_tribble=false -Dsamjdk.compression_level=2 -jar /opt/gatk/gatk-package-4.4.0.0-local.jar AddOrReplaceReadGroups -I /content/drive/MyDrive/Cancer_WES_Project/bam_files/SRR1952986_sorted.bam -O /content/drive/MyDrive/Cancer_WES_Project/bam_files/SRR1952986_RG.bam -RGID 1 -RGLB lib1 -RGPL illumina -RGPU unit1 -RGSM SRR1952986
# 13:21:10.338 INFO  NativeLibraryLoader - Loading libgkl_compression.so from jar:file:/opt/gatk/gatk-package-4.4.0.0-local.jar!/com/intel/gkl/native/libgkl_compression.so
# [Fri Jul 18 13:21:10 UTC 2025] AddOrReplaceReadGroups --INPUT /content/drive/MyDrive/Cancer_WES_Project/bam_files/SRR1952986_sorted.bam --OUTPUT /content/drive/MyDrive/Cancer_WES_Project/bam_files/SRR1952986_RG.bam --RGID 1 --RGLB lib1 --RGPL illumina --RGPU unit1 --RGSM SRR1952986 --VERBOSITY INFO --QUIET false --VALIDATION_STRINGENCY STRICT --COMPRESSION_LEVEL 2 --MAX_RECORDS_IN_RAM 500000 --CREATE_INDEX false --CREATE_MD5_FILE false --help false --version false --showHidden false --USE_JDK_DEFLATER false --USE_JDK_INFLATER false
# [Fri Jul 18 13:21:10 UTC 2025] Executing as root@c319e878d953 on Linux 6.1.123+ amd64; OpenJDK 64-Bit Server VM 17.0.15+6-Ubuntu-0ubuntu122.04; Deflater: Intel; Inflater: Intel; Provider GCS is available; Picard version: Version:4.4.0.0
# INFO	2025-07-18 13:21:11	AddOrReplaceReadGroups	Created read-group ID=1 PL=illumina LB=lib1 SM=SRR1952986
#
# INFO	2025-07-18 13:21:22	AddOrReplaceReadGroups	Processed     1,000,000 records.  Elapsed time: 00:00:10s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:21:33	AddOrReplaceReadGroups	Processed     2,000,000 records.  Elapsed time: 00:00:21s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:21:40	AddOrReplaceReadGroups	Processed     3,000,000 records.  Elapsed time: 00:00:29s.  Time for last 1,000,000:    7s.  Last read position: */*
# INFO	2025-07-18 13:21:51	AddOrReplaceReadGroups	Processed     4,000,000 records.  Elapsed time: 00:00:39s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:21:59	AddOrReplaceReadGroups	Processed     5,000,000 records.  Elapsed time: 00:00:48s.  Time for last 1,000,000:    8s.  Last read position: */*
# INFO	2025-07-18 13:22:09	AddOrReplaceReadGroups	Processed     6,000,000 records.  Elapsed time: 00:00:57s.  Time for last 1,000,000:    9s.  Last read position: */*
# INFO	2025-07-18 13:22:18	AddOrReplaceReadGroups	Processed     7,000,000 records.  Elapsed time: 00:01:07s.  Time for last 1,000,000:    9s.  Last read position: */*
# INFO	2025-07-18 13:22:27	AddOrReplaceReadGroups	Processed     8,000,000 records.  Elapsed time: 00:01:15s.  Time for last 1,000,000:    8s.  Last read position: */*
# INFO	2025-07-18 13:22:37	AddOrReplaceReadGroups	Processed     9,000,000 records.  Elapsed time: 00:01:25s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:22:44	AddOrReplaceReadGroups	Processed    10,000,000 records.  Elapsed time: 00:01:33s.  Time for last 1,000,000:    7s.  Last read position: */*
# INFO	2025-07-18 13:22:55	AddOrReplaceReadGroups	Processed    11,000,000 records.  Elapsed time: 00:01:44s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:23:03	AddOrReplaceReadGroups	Processed    12,000,000 records.  Elapsed time: 00:01:51s.  Time for last 1,000,000:    7s.  Last read position: */*
# INFO	2025-07-18 13:23:13	AddOrReplaceReadGroups	Processed    13,000,000 records.  Elapsed time: 00:02:02s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:23:21	AddOrReplaceReadGroups	Processed    14,000,000 records.  Elapsed time: 00:02:09s.  Time for last 1,000,000:    7s.  Last read position: */*
# INFO	2025-07-18 13:23:31	AddOrReplaceReadGroups	Processed    15,000,000 records.  Elapsed time: 00:02:20s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:23:39	AddOrReplaceReadGroups	Processed    16,000,000 records.  Elapsed time: 00:02:27s.  Time for last 1,000,000:    7s.  Last read position: */*
# INFO	2025-07-18 13:23:49	AddOrReplaceReadGroups	Processed    17,000,000 records.  Elapsed time: 00:02:38s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:23:57	AddOrReplaceReadGroups	Processed    18,000,000 records.  Elapsed time: 00:02:46s.  Time for last 1,000,000:    8s.  Last read position: */*
# INFO	2025-07-18 13:24:13	AddOrReplaceReadGroups	Processed    19,000,000 records.  Elapsed time: 00:03:01s.  Time for last 1,000,000:   15s.  Last read position: */*
# INFO	2025-07-18 13:24:26	AddOrReplaceReadGroups	Processed    20,000,000 records.  Elapsed time: 00:03:15s.  Time for last 1,000,000:   13s.  Last read position: */*
# INFO	2025-07-18 13:24:37	AddOrReplaceReadGroups	Processed    21,000,000 records.  Elapsed time: 00:03:26s.  Time for last 1,000,000:   10s.  Last read position: */*
# INFO	2025-07-18 13:24:46	AddOrReplaceReadGroups	Processed    22,000,000 records.  Elapsed time: 00:03:35s.  Time for last 1,000,000:    9s.  Last read position: */*
# INFO	2025-07-18 13:24:58	AddOrReplaceReadGroups	Processed    23,000,000 records.  Elapsed time: 00:03:46s.  Time for last 1,000,000:   11s.  Last read position: */*
# INFO	2025-07-18 13:25:05	AddOrReplaceReadGroups	Processed    24,000,000 records.  Elapsed time: 00:03:54s.  Time for last 1,000,000:    7s.  Last read position: */*
# [Fri Jul 18 13:25:05 UTC 2025] picard.sam.AddOrReplaceReadGroups done. Elapsed time: 3.92 minutes.
# Runtime.totalMemory()=163577856
# Tool returned:
# 0
# total 8.4G
# -rw------- 1 root root 2.4G Jul 18 13:15 SRR1952986_raw.bam
# -rw------- 1 root root 3.7G Jul 18 13:25 SRR1952986_RG.bam
# -rw------- 1 root root 2.7M Jul 18 13:25 SRR1952986_RG.bam.bai
# -rw------- 1 root root 2.4G Jul 18 13:21 SRR1952986_sorted.bam

# %%
vcf_dir = "/content/drive/MyDrive/Cancer_WES_Project/vcf_files"
bcf_file = f"{vcf_dir}/{sample_id}_raw.bcf"
vcf_file = f"{vcf_dir}/{sample_id}_raw.vcf"

# Generate BCF (binary variant file)
# !bcftools mpileup -Ou -f {ref} {rg_bam} | bcftools call -mv -Ob -o {bcf_file}

# Convert BCF to human-readable VCF
# !bcftools view {bcf_file} -Ov -o {vcf_file}

# List result
# !ls -lh {vcf_dir}
# Out:
# Note: none of --samples-file, --ploidy or --ploidy-file given, assuming all sites are diploid
# [mpileup] 1 samples in 1 input files
# [mpileup] maximum number of reads per input file set to -d 250
# total 760K
# -rw------- 1 root root  79K Jul 18 13:32 SRR1952986_raw.bcf
# -rw------- 1 root root 681K Jul 18 13:32 SRR1952986_raw.vcf

# %%
# ✅ Move to reference folder
# %cd /content/drive/MyDrive/Cancer_WES_Project/reference

# ✅ Download GENCODE v44 annotation GTF (only chr info needed for csq)
# !wget -c https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_44/gencode.v44.annotation.gtf.gz

# ✅ Index the GTF file (required by bcftools csq)
# !bcftools index gencode.v44.annotation.gtf.gz
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/reference
# --2025-07-18 14:14:48--  https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_44/gencode.v44.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49721965 (47M) [application/x-gzip]
# Saving to: ‘gencode.v44.annotation.gtf.gz’
#
# gencode.v44.annotat 100%[===================>]  47.42M  22.7MB/s    in 2.1s
#
# 2025-07-18 14:14:51 (22.7 MB/s) - ‘gencode.v44.annotation.gtf.gz’ saved [49721965/49721965]
#
# index: the file is not BGZF compressed, cannot index: gencode.v44.annotation.gtf.gz

# %%
# Move to a working directory (e.g., ref folder)
# %cd /content/drive/MyDrive/Cancer_WES_Project/reference

# Download HTSlib source
# !wget https://github.com/samtools/htslib/releases/download/1.22.1/htslib-1.22.1.tar.bz2

# Extract, build, and install locally
# !tar -xjf htslib-1.22.1.tar.bz2
# %cd htslib-1.22.1
# !./configure --prefix=$PWD/../htslib_install
# !make -j2
# !make install

# Update PATH to include best compiled binaries
import os
os.environ["PATH"] = os.environ["PATH"] + ":" + os.path.join(os.getcwd(), "../htslib_install/bin")
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/reference
# --2025-07-18 14:15:05--  https://github.com/samtools/htslib/releases/download/1.22.1/htslib-1.22.1.tar.bz2
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/4339773/2fcb9687-d889-4790-a4bd-efb525669bbd?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-18T15%3A10%3A45Z&rscd=attachment%3B+filename%3Dhtslib-1.22.1.tar.bz2&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-18T14%3A10%3A18Z&ske=2025-07-18T15%3A10%3A45Z&sks=b&skv=2018-11-09&sig=4qoWohsotrD2Bg6zKjHXMwKCBJ331kE3XF3AMcrOwmY%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1Mjg0ODQwNSwibmJmIjoxNzUyODQ4MTA1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.WEc0GhpJwr-j4zYZ3KmgJlI0pLnxmDDZt4EzDSYTXA0&response-content-disposition=attachment%3B%20filename%3Dhtslib-1.22.1.tar.bz2&response-content-type=application%2Foctet-stream [following]
# --2025-07-18 14:15:06--  https://release-assets.githubusercontent.com/github-production-release-asset/4339773/2fcb9687-d889-4790-a4bd-efb525669bbd?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-18T15%3A10%3A45Z&rscd=attachment%3B+filename%3Dhtslib-1.22.1.tar.bz2&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-18T14%3A10%3A18Z&ske=2025-07-18T15%3A10%3A45Z&sks=b&skv=2018-11-09&sig=4qoWohsotrD2Bg6zKjHXMwKCBJ331kE3XF3AMcrOwmY%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1Mjg0ODQwNSwibmJmIjoxNzUyODQ4MTA1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.WEc0GhpJwr-j4zYZ3KmgJlI0pLnxmDDZt4EzDSYTXA0&response-content-disposition=attachment%3B%20filename%3Dhtslib-1.22.1.tar.bz2&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4840271 (4.6M) [application/octet-stream]
# Saving to: ‘htslib-1.22.1.tar.bz2.1’
#
# htslib-1.22.1.tar.b 100%[===================>]   4.62M  26.5MB/s    in 0.2s
#
# 2025-07-18 14:15:06 (26.5 MB/s) - ‘htslib-1.22.1.tar.bz2.1’ saved [4840271/4840271]
#
# /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether the compiler supports GNU C... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to enable C11 features... none needed
# checking for ranlib... ranlib
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for C compiler warning flags... -Wall
# checking for gcc options needed to detect all undeclared functions... none needed
# checking for stdio.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for strings.h... yes
# checking for sys/stat.h... yes
# checking for sys/types.h... yes
# checking for unistd.h... yes
# checking for sys/param.h... yes
# checking whether _XOPEN_SOURCE is declared... no
# checking whether __get_cpuid_max is declared... yes
# checking whether __cpuid_count is declared... yes
# checking C compiler flags needed for sse4.1... -msse4.1 -mssse3 -mpopcnt
# checking C compiler flags needed for avx2... -mavx2 -mpopcnt
# checking C compiler flags needed for avx512f... -mavx512f -mpopcnt
# checking for working __builtin_cpu_supports("ssse3")... yes
# checking for working __attribute__((target("ssse3")))... yes
# checking for pkg-config... /usr/bin/pkg-config
# checking pkg-config is at least version 0.9.0... yes
# checking for gcc option to enable large file support... none needed
# checking shared library type for unknown-Linux... plain .so
# checking whether the linker supports versioned symbols... yes
# checking whether the compiler accepts -fvisibility=hidden... yes
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking for getpagesize... yes
# checking for working mmap... yes
# checking for gmtime_r... yes
# checking for fsync... yes
# checking for drand48... yes
# checking for srand48_deterministic... no
# checking for getauxval... yes
# checking for elf_aux_info... no
# checking for posix_memalign... yes
# checking whether fdatasync is declared... yes
# checking for fdatasync... yes
# checking for __attribute__((constructor))... yes
# checking for clock_gettime with CLOCK_PROCESS_CPUTIME_ID... yes
# checking for library containing log... -lm
# checking for zlib.h... yes
# checking for inflate in -lz... yes
# checking for library containing recv... none required
# checking for bzlib.h... yes
# checking for BZ2_bzBuffToBuffCompress in -lbz2... yes
# checking for lzma.h... yes
# checking for lzma_easy_buffer_encode in -llzma... yes
# checking whether htscodecs files are present... yes
# checking for libdeflate.h... yes
# checking for libdeflate_deflate_compress in -ldeflate... yes
# checking for curl/curl.h... yes
# checking for curl_easy_pause in -lcurl... yes
# checking for CCHmac... no
# checking for library containing HMAC... -lcrypto
# checking for CMSG_LEN... yes
# checking for epoll... yes (edge triggered)
# checking for sendfile... yes, Linux-style
# checking whether EHOSTDOWN is declared... yes
# checking whether ENONET is declared... yes
# checking whether AI_V4MAPPED is declared... yes
# checking whether AI_ADDRCONFIG is declared... yes
# checking whether the compiler accepts -Wextra... yes
# checking whether the compiler accepts -Wformat... yes
# checking whether the compiler accepts -Wformat=2... yes
# checking whether the compiler accepts -Wconversion... yes
# checking whether the compiler accepts -Wtrampolines... yes
# checking whether the compiler accepts -Wstrict-aliasing... yes
# checking whether the compiler accepts -fstack-clash-protection... yes
# checking whether the compiler accepts -fstack-protector-strong... yes
# checking whether the compiler accepts -fcf-protection=full... yes
# checking whether the compiler accepts -mbranch-protection=standard... no
# checking whether the compiler accepts -fno-delete-null-pointer-checks... yes
# checking whether the compiler accepts -Wl,-z,noexecstack... yes
# checking whether the compiler accepts -Wl,-z,relro... yes
# checking whether the compiler accepts -Wl,-z,now... yes
# checking whether the compiler accepts -Wl,--as-needed... yes
# checking whether the compiler accepts -Wl,--no-copy-dt-needed-entries... yes
# checking whether the compiler accepts -Wl,-z,nodlopen... yes
# checking for library containing regcomp... none required
# configure: creating ./config.status
# config.status: creating config.mk
# config.status: creating htslib.pc.tmp
# config.status: creating config.h
# config.status: config.h is unchanged
# config.status: linking htscodecs_bundled.mk to htscodecs.mk
# sed -n '/^static_libs=/s/[^=]*=/HTSLIB_static_LIBS = /p;/^static_ldflags=/s/[^=]*=/HTSLIB_static_LDFLAGS = /p' htslib.pc.tmp > htslib_static.mk
# sed -e "s#@-includedir@#`pwd`#g;s#@-libdir@#`pwd`#g" htslib.pc.tmp > htslib-uninstalled.pc
# mkdir -p -m 755 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/bin /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/include /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/include/htslib /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/share/man/man1 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/share/man/man5 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/share/man/man7 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib/pkgconfig
# if test -n ""; then mkdir -p -m 755 ; fi
# install -p -m 644 libhts.so /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib/libhts.so.1.22.1
# ln -sf libhts.so.1.22.1 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib/libhts.so
# ln -sf libhts.so.1.22.1 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib/libhts.so.3
# sed -e 's#@-includedir@#/content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/include#g;s#@-libdir@#/content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib#g;s#@-PACKAGE_VERSION@#1.22.1#g' htslib.pc.tmp > /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib/pkgconfig/htslib.pc
# chmod 644 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib/pkgconfig/htslib.pc
# install -p annot-tsv bgzip htsfile tabix ref_cache/ref-cache /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/bin
# if test -n ""; then install -p  ; fi
# install -p -m 644 htslib/*.h /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/include/htslib
# install -p -m 644 libhts.a /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/lib/libhts.a
# install -p -m 644 annot-tsv.1 bgzip.1 htsfile.1 tabix.1 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/share/man/man1
# if test "xref_cache/ref-cache" != "x" ; then \
#     install -p -m 644 ref_cache/ref-cache.1 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/share/man/man1 ; \
# fi
# install -p -m 644 faidx.5 sam.5 vcf.5 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/share/man/man5
# install -p -m 644 htslib-s3-plugin.7 /content/drive/MyDrive/Cancer_WES_Project/reference/htslib-1.22.1/../htslib_install/share/man/man7

# %%
# ✅ Move to reference folder
# %cd /content/drive/MyDrive/Cancer_WES_Project/reference

# ✅ Clean up any broken or double files
# !rm -f gencode.v44.annotation.gtf.gz*
# !rm -f gencode.v44.annotation.gtf

# ✅ Download fresh, correct GTF file
# !wget -c https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_44/gencode.v44.annotation.gtf.gz

# ✅ Decompress just enough to get .gtf (not .gz.gz!)
# !gunzip -f gencode.v44.annotation.gtf.gz

# ✅ Recompress it using BGZIP (required for tabix)
# !bgzip -c gencode.v44.annotation.gtf > gencode.v44.annotation.gtf.gz

# ✅ Index using tabix for use with bcftools csq
# !tabix -p gtf gencode.v44.annotation.gtf.gz

# ✅ Confirm output
# !ls -lh gencode.v44.annotation.gtf.gz*
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/reference
# --2025-07-18 14:15:42--  https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_44/gencode.v44.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49721965 (47M) [application/x-gzip]
# Saving to: ‘gencode.v44.annotation.gtf.gz’
#
# gencode.v44.annotat 100%[===================>]  47.42M  2.27MB/s    in 36s
#
# 2025-07-18 14:16:19 (1.30 MB/s) - ‘gencode.v44.annotation.gtf.gz’ saved [49721965/49721965]
#
# The preset string not recognised: 'gtf'
# -rw------- 1 root root 60M Jul 18 14:16 gencode.v44.annotation.gtf.gz

# %%
# Step 1: Move into the reference folder
# %cd /content/drive/MyDrive/Cancer_WES_Project/reference

# Step 2: Uncompress GTF
# !gunzip -f gencode.v44.annotation.gtf.gz

# Step 3: Sort the GTF file by chromosome and start position
# !sort -k1,1 -k4,4n gencode.v44.annotation.gtf > gencode.v44.sorted.gtf

# Step 4: Compress the sorted GTF with bgzip
# !bgzip -f gencode.v44.sorted.gtf

# Step 5: Index with tabix (correct preset!)
# !tabix -p gff gencode.v44.sorted.gtf.gz
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/reference

# %%
# Step 1: Go to reference folder
# %cd /content/drive/MyDrive/Cancer_WES_Project/reference

# Step 2: Download the correct GFF3 file (not GTF!)
# !wget -c https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_44/gencode.v44.annotation.gff3.gz

# Step 3: Sort, compress, and index it
# !gunzip -f gencode.v44.annotation.gff3.gz
# !sort -k1,1 -k4,4n gencode.v44.annotation.gff3 > gencode.v44.sorted.gff3
# !bgzip -f gencode.v44.sorted.gff3
# !tabix -p gff gencode.v44.sorted.gff3.gz
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/reference
# --2025-07-18 14:19:11--  https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_44/gencode.v44.annotation.gff3.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60727700 (58M) [application/x-gzip]
# Saving to: ‘gencode.v44.annotation.gff3.gz’
#
# gencode.v44.annotat 100%[===================>]  57.91M  23.6MB/s    in 2.4s
#
# 2025-07-18 14:19:14 (23.6 MB/s) - ‘gencode.v44.annotation.gff3.gz’ saved [60727700/60727700]

# %%
# %%bash
# awk 'BEGIN {OFS="\t"} {
#   if ($3 ~ /exon|CDS|five_prime_UTR|three_prime_UTR|start_codon|stop_codon/) {
#     split($9, attrs, ";");
#     for (i in attrs) {
#       if (attrs[i] ~ /^Parent=/) {
#         parent_val = substr(attrs[i], 8);
#         if (parent_val !~ /^transcript:/) {
#           attrs[i] = "Parent=transcript:" parent_val;
#         }
#       }
#     }
#     $9 = attrs[1];
#     for (i = 2; i in attrs; i++) {
#       $9 = $9 ";" attrs[i];
#     }
#   }
#   print
# }' gencode.v44.annotation.gff3 > fixed2.gff3

# %%
# !sort -k1,1 -k4,4n fixed2.gff3 > fixed2.sorted.gff3
# !bgzip -f fixed2.sorted.gff3
# !tabix -p gff fixed2.sorted.gff3.gz

# %%
# Go to reference directory
# %cd /content/drive/MyDrive/Cancer_WES_Project/reference

# ✅ Download the GRCh38 reference genome (~834MB compressed)
# !wget -O GRCh38_no_alt_plus_decoy.fa.gz "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.40_GRCh38.p14/GRCh38_major_release_seqs_for_alignment_pipelines/GCA_000001405.15_GRCh38_no_alt_plus_hs38d1_analysis_set.fna.gz"

# ✅ Decompress the FASTA
# !gunzip -f GRCh38_no_alt_plus_decoy.fa.gz
# Out:
# /content/drive/MyDrive/Cancer_WES_Project/reference
# --2025-07-18 14:38:50--  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/405/GCF_000001405.40_GRCh38.p14/GRCh38_major_release_seqs_for_alignment_pipelines/GCA_000001405.15_GRCh38_no_alt_plus_hs38d1_analysis_set.fna.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.10, 130.14.250.11, 130.14.250.12, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 874637925 (834M) [application/x-gzip]
# Saving to: ‘GRCh38_no_alt_plus_decoy.fa.gz’
#
# GRCh38_no_alt_plus_ 100%[===================>] 834.12M  35.9MB/s    in 22s
#
# 2025-07-18 14:39:13 (37.1 MB/s) - ‘GRCh38_no_alt_plus_decoy.fa.gz’ saved [874637925/874637925]

# %%
# Create FASTA index (bcftools needs this!)
# !samtools faidx /content/drive/MyDrive/Cancer_WES_Project/reference/GRCh38_no_alt_plus_decoy.fa

# %%
# !bcftools csq \
  -f /content/drive/MyDrive/Cancer_WES_Project/reference/GRCh38_no_alt_plus_decoy.fa \
  -g /content/drive/MyDrive/Cancer_WES_Project/reference/fixed2.sorted.gff3.gz \
  -o /content/drive/MyDrive/Cancer_WES_Project/vcf_files/SRR1952986_annotated.vcf \
  -Ov \
  /content/drive/MyDrive/Cancer_WES_Project/vcf_files/SRR1952986_raw.vcf
# Out:
# Streaming output truncated to the last 5000 lines.
# ignored: chrX	HAVANA	start_codon	136879425	136879427	.	-	0	ID=start_codon:ENST00000562646.5;Parent=transcript:ENST00000562646.5;gene_id=ENSG00000147274.14;transcript_id=ENST00000562646.5;gene_type=protein_coding;gene_name=RBMX;transcript_type=protein_coding;transcript_name=RBMX-207;exon_number=2;exon_id=ENSE00003532874.1;level=2;protein_id=ENSP00000457051.1;transcript_support_level=1;hgnc_id=HGNC:9910;tag=basic;havana_gene=OTTHUMG00000022517.2;havana_transcript=OTTHUMT00000420447.1
# ignored: chrX	HAVANA	start_codon	136879425	136879427	.	-	0	ID=start_codon:ENST00000563370.1;Parent=transcript:ENST00000563370.1;gene_id=ENSG00000147274.14;transcript_id=ENST00000563370.1;gene_type=protein_coding;gene_name=RBMX;transcript_type=nonsense_mediated_decay;transcript_name=RBMX-208;exon_number=2;exon_id=ENSE00003532874.1;level=2;protein_id=ENSP00000454777.1;transcript_support_level=3;hgnc_id=HGNC:9910;havana_gene=OTTHUMG00000022517.2;havana_transcript=OTTHUMT00000420450.1
gene_type=lncRNA;gene_name=ENSG00000291054;transcript_type=lncRNA;transcript_name=ENST00000693698;level=2;tag=TAGENE
# ignored: chrX	HAVANA	gene	136947748	136948133	.	-	.	ID=ENSG00000232379.1;gene_id=ENSG00000232379.1;gene_type=processed_pseudogene;gene_name=RPL22P23;level=1;hgnc_id=HGNC:53759;tag=pseudo_consens;havana_gene=OTTHUMG00000040140.1
# ignored: chrX	HAVANA	transcript	136947748	136948133	.	-	.	ID=ENST00000439143.1;Parent=ENSG00000232379.1;gene_id=ENSG00000232379.1;transcript_id=ENST00000439143.1;gene_type=processed_pseudogene;gene_name=RPL22P23;transcript_type=processed_pseudogene;transcript_name=RPL22P23-201;level=1;transcript_support_level=NA;hgnc_id=HGNC:53759;ont=PGO:0000004;tag=pseudo_consens,basic,Ensembl_canonical;havana_gene=OTTHUMG00000040140.1;havana_transcript=OTTHUMT00000096794.1
# ignored: chrX	HAVANA	gene	136958883	137021479	.	+	.	ID=ENSG00000234062.11;gene_id=ENSG00000234062.11;gene_type=transcribed_unprocessed_pseudogene;gene_name=TM9SF5P;level=2;hgnc_id=HGNC:55623;havana_gene=OTTHUMG00000040141.3
# ignored: chrX	HAVANA	transcript	136958883	137021479	.	+	.	ID=ENST00000426943.4;Parent=ENSG00000234062.11;gene_id=ENSG00000234062.11;transcript_id=ENST00000426943.4;gene_type=transcribed_unprocessed_pseudogene;gene_name=TM9SF5P;transcript_type=transcribed_unprocessed_pseudogene;transcript_name=TM9SF5P-201;level=2;transcript_support_level=NA;hgnc_id=HGNC:55623;ont=PGO:0000005,PGO:0000019;tag=basic,Ensembl_canonical;havana_gene=OTTHUMG00000040141.3;havana_transcript=OTTHUMT00000096795.2
# ignored: chrX	HAVANA	gene	136976417	136985705	.	-	.	ID=ENSG00000237307.2;gene_id=ENSG00000237307.2;gene_type=processed_pseudogene;gene_name=SRRM1P3;level=1;hgnc_id=HGNC:38164;tag=pseudo_consens;havana_gene=OTTHUMG00000022520.2
# ignored: chrX	HAVANA	transcript	136976417	136985705	.	-	.	ID=ENST00000426911.2;Parent=ENSG00000237307.2;gene_id=ENSG00000237307.2;transcript_id=ENST00000426911.2;gene_type=processed_pseudogene;gene_name=SRRM1P3;transcript_type=processed_pseudogene;transcript_name=SRRM1P3-201;level=1;transcript_support_level=NA;hgnc_id=HGNC:38164;ont=PGO:0000004;tag=pseudo_consens,basic,Ensembl_canonical;havana_gene=OTTHUMG00000022520.2;havana_transcript=OTTHUMT00000058518.2
# ignored: chrX	HAVANA	transcript	136993487	137021630	.	+	.	ID=ENST00000438602.5;Parent=ENSG00000291054.1;gene_id=ENSG00000291054.1;transcript_id=ENST00000438602.5;gene_type=lncRNA;gene_name=ENSG00000291054;transcript_type=lncRNA;transcript_name=ENST00000438602;level=2;transcript_support_level=3;havana_transcript=OTTHUMT00000479627.1
# ignored: chrX	HAVANA	transcript	136993554	137021618	.	+	.	ID=ENST00000440604.2;Parent=ENSG00000291054.1;gene_id=ENSG00000291054.1;transcript_id=ENST00000440604.2;gene_type=lncRNA;gene_name=ENSG00000291054;transcript_type=lncRNA;transcript_name=ENST00000440604;level=2;transcript_support_level=5;havana_transcript=OTTHUMT00000479628.1
# ignored: chrX	HAVANA	gene	137023929	137033995	.	-	.	ID=ENSG00000165370.3;gene_id=ENSG00000165370.3;gene_type=protein_coding;gene_name=GPR101;level=2;hgnc_id=HGNC:14963;havana_gene=OTTHUMG00000022521.4
# ignored: chrX	HAVANA	transcript	137023929	137033995	.	-	.	ID=ENST00000651716.2;Parent=ENSG00000165370.3;gene_id=ENSG00000165370.3;transcript_id=ENST00000651716.2;gene_type=protein_coding;gene_name=GPR101;transcript_type=protein_coding;transcript_name=GPR101-201;level=2;protein_id=ENSP00000498972.1;hgnc_id=HGNC:14963;tag=CAGE_supported_TSS,RNA_Seq_supported_partial,basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS14662.1;havana_gene=OTTHUMG00000022521.4;havana_transcript=OTTHUMT00000058519.3
# ignored: chrX	HAVANA	stop_codon	137030148	137030150	.	-	0	ID=stop_codon:ENST00000651716.2;Parent=transcript:ENST00000651716.2;gene_id=ENSG00000165370.3;transcript_id=ENST00000651716.2;gene_type=protein_coding;gene_name=GPR101;transcript_type=protein_coding;transcript_name=GPR101-201;exon_number=2;exon_id=ENSE00003841647.2;level=2;protein_id=ENSP00000498972.1;hgnc_id=HGNC:14963;tag=CAGE_supported_TSS,RNA_Seq_supported_partial,basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS14662.1;havana_gene=OTTHUMG00000022521.4;havana_transcript=OTTHUMT00000058519.3
# ignored: chrX	HAVANA	start_codon	137031672	137031674	.	-	0	ID=start_codon:ENST00000651716.2;Parent=transcript:ENST00000651716.2;gene_id=ENSG00000165370.3;transcript_id=ENST00000651716.2;gene_type=protein_coding;gene_name=GPR101;transcript_type=protein_coding;transcript_name=GPR101-201;exon_number=2;exon_id=ENSE00003841647.2;level=2;protein_id=ENSP00000498972.1;hgnc_id=HGNC:14963;tag=CAGE_supported_TSS,RNA_Seq_supported_partial,basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS14662.1;havana_gene=OTTHUMG00000022521.4;havana_transcript=OTTHUMT00000058519.3
# ignored: chrX	HAVANA	gene	137324972	137325049	.	-	.	ID=ENSG00000214748.2;gene_id=ENSG00000214748.2;gene_type=processed_pseudogene;gene_name=ENSG00000214748;level=2;havana_gene=OTTHUMG00000022522.1
# ignored: chrX	HAVANA	transcript	137324972	137325049	.	-	.	ID=ENST00000442158.1;Parent=ENSG00000214748.2;gene_id=ENSG00000214748.2;transcript_id=ENST00000442158.1;gene_type=processed_pseudogene;gene_name=ENSG00000214748;transcript_type=processed_pseudogene;transcript_name=ENST00000442158;level=2;transcript_support_level=NA;ont=PGO:0000004;tag=basic,Ensembl_canonical;havana_gene=OTTHUMG00000022522.1;havana_transcript=OTTHUMT00000058520.1
# ignored: chrX	HAVANA	gene	137441258	137441836	.	-	.	ID=ENSG00000237584.1;gene_id=ENSG00000237584.1;gene_type=processed_pseudogene;gene_name=RAC1P4;level=1;hgnc_id=HGNC:31113;tag=pseudo_consens;havana_gene=OTTHUMG00000022523.3
# ignored: chrX	HAVANA	transcript	137441258	137441836	.	-	.	ID=ENST00000419413.1;Parent=ENSG00000237584.1;gene_id=ENSG00000237584.1;transcript_id=ENST00000419413.1;gene_type=processed_pseudogene;gene_name=RAC1P4;transcript_type=processed_pseudogene;transcript_name=RAC1P4-201;level=1;transcript_support_level=NA;hgnc_id=HGNC:31113;ont=PGO:0000004;tag=pseudo_consens,basic,Ensembl_canonical;havana_gene=OTTHUMG00000022523.3;havana_transcript=OTTHUMT00000058521.2
# ignored: chrX	HAVANA	gene	137556191	137564488	.	-	.	ID=ENSG00000224765.2;gene_id=ENSG00000224765.2;gene_type=lncRNA;gene_name=LINC02931;level=2;hgnc_id=HGNC:55853;havana_gene=OTTHUMG00000022524.1
# ignored: chrX	HAVANA	transcript	137556191	137563925	.	-	.	ID=ENST00000456631.1;Parent=ENSG00000224765.2;gene_id=ENSG00000224765.2;transcript_id=ENST00000456631.1;gene_type=lncRNA;gene_name=LINC02931;transcript_type=lncRNA;transcript_name=LINC02931-202;level=2;transcript_support_level=3;hgnc_id=HGNC:55853;havana_gene=OTTHUMG00000022524.1;havana_transcript=OTTHUMT00000058522.1
# ignored: chrX	HAVANA	transcript	137556191	137564484	.	-	.	ID=ENST00000690456.1;Parent=ENSG00000224765.2;gene_id=ENSG00000224765.2;transcript_id=ENST00000690456.1;gene_type=lncRNA;gene_name=LINC02931;transcript_type=lncRNA;transcript_name=LINC02931-204;level=2;hgnc_id=HGNC:55853;tag=basic,TAGENE;havana_gene=OTTHUMG00000022524.1
# ignored: chrX	HAVANA	transcript	137556191	137564488	.	-	.	ID=ENST00000689992.1;Parent=ENSG00000224765.2;gene_id=ENSG00000224765.2;transcript_id=ENST00000689992.1;gene_type=lncRNA;gene_name=LINC02931;transcript_type=lncRNA;transcript_name=LINC02931-203;level=2;hgnc_id=HGNC:55853;tag=Ensembl_canonical,TAGENE;havana_gene=OTTHUMG00000022524.1
# ignored: chrX	HAVANA	transcript	137560669	137564487	.	-	.	ID=ENST00000442841.2;Parent=ENSG00000224765.2;gene_id=ENSG00000224765.2;transcript_id=ENST00000442841.2;gene_type=lncRNA;gene_name=LINC02931;transcript_type=lncRNA;transcript_name=LINC02931-201;level=2;transcript_support_level=2;hgnc_id=HGNC:55853;tag=basic,TAGENE;havana_gene=OTTHUMG00000022524.1;havana_transcript=OTTHUMT00000058523.1
# ignored: chrX	HAVANA	gene	137566127	137577691	.	+	.	ID=ENSG00000156925.12;gene_id=ENSG00000156925.12;gene_type=protein_coding;gene_name=ZIC3;level=2;hgnc_id=HGNC:12874;tag=overlapping_locus;havana_gene=OTTHUMG00000022525.2
# ignored: chrX	HAVANA	transcript	137566127	137572102	.	+	.	ID=ENST00000287538.10;Parent=ENSG00000156925.12;gene_id=ENSG00000156925.12;transcript_id=ENST00000287538.10;gene_type=protein_coding;gene_name=ZIC3;transcript_type=protein_coding;transcript_name=ZIC3-201;level=2;protein_id=ENSP00000287538.5;transcript_support_level=1;hgnc_id=HGNC:12874;tag=basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS14663.1;havana_gene=OTTHUMG00000022525.2;havana_transcript=OTTHUMT00000058526.2
# ignored: chrX	HAVANA	transcript	137566518	137577691	.	+	.	ID=ENST00000370606.3;Parent=ENSG00000156925.12;gene_id=ENSG00000156925.12;transcript_id=ENST00000370606.3;gene_type=protein_coding;gene_name=ZIC3;transcript_type=protein_coding;transcript_name=ZIC3-202;level=2;protein_id=ENSP00000359638.3;transcript_support_level=5;hgnc_id=HGNC:12874;tag=basic,CCDS;ccdsid=CCDS83494.1;havana_gene=OTTHUMG00000022525.2;havana_transcript=OTTHUMT00000058524.1
# ignored: chrX	HAVANA	start_codon	137566692	137566694	.	+	0	ID=start_codon:ENST00000287538.10;Parent=transcript:ENST00000287538.10;gene_id=ENSG00000156925.12;transcript_id=ENST00000287538.10;gene_type=protein_coding;gene_name=ZIC3;transcript_type=protein_coding;transcript_name=ZIC3-201;exon_number=1;exon_id=ENSE00001297697.7;level=2;protein_id=ENSP00000287538.5;transcript_support_level=1;hgnc_id=HGNC:12874;tag=basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS14663.1;havana_gene=OTTHUMG00000022525.2;havana_transcript=OTTHUMT00000058526.2
# ignored: chrX	HAVANA	start_codon	137566692	137566694	.	+	0	ID=start_codon:ENST00000370606.3;Parent=transcript:ENST00000370606.3;gene_id=ENSG00000156925.12;transcript_id=ENST00000370606.3;gene_type=protein_coding;gene_name=ZIC3;transcript_type=protein_coding;transcript_name=ZIC3-202;exon_number=1;exon_id=ENSE00001824058.1;level=2;protein_id=ENSP00000359638.3;transcript_support_level=5;hgnc_id=HGNC:12874;tag=basic,CCDS;ccdsid=CCDS83494.1;havana_gene=OTTHUMG00000022525.2;havana_transcript=OTTHUMT00000058524.1
# ignored: chrX	HAVANA	transcript	137568805	137569995	.	+	.	ID=ENST00000478471.1;Parent=ENSG00000156925.12;gene_id=ENSG00000156925.12;transcript_id=ENST00000478471.1;gene_type=protein_coding;gene_name=ZIC3;transcript_type=protein_coding_CDS_not_defined;transcript_name=ZIC3-203;level=2;transcript_support_level=2;hgnc_id=HGNC:12874;havana_gene=OTTHUMG00000022525.2;havana_transcript=OTTHUMT00000058525.1
# ignored: chrX	HAVANA	stop_codon	137570068	137570070	.	+	0	ID=stop_codon:ENST00000287538.10;Parent=transcript:ENST00000287538.10;gene_id=ENSG00000156925.12;transcript_id=ENST00000287538.10;gene_type=protein_coding;gene_name=ZIC3;transcript_type=protein_coding;transcript_name=ZIC3-201;exon_number=3;exon_id=ENSE00001029121.6;level=2;protein_id=ENSP00000287538.5;transcript_support_level=1;hgnc_id=HGNC:12874;tag=basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS14663.1;havana_gene=OTTHUMG00000022525.2;havana_transcript=OTTHUMT00000058526.2
# ignored: chrX	HAVANA	gene	137573752	137981780	.	+	.	ID=ENSG00000283692.2;gene_id=ENSG00000283692.2;gene_type=lncRNA;gene_name=ENSG00000283692;level=2;tag=ncRNA_host,overlapping_locus;havana_gene=OTTHUMG00000191795.2
# ignored: chrX	HAVANA	transcript	137573752	137981381	.	+	.	ID=ENST00000637564.1;Parent=ENSG00000283692.2;gene_id=ENSG00000283692.2;transcript_id=ENST00000637564.1;gene_type=lncRNA;gene_name=ENSG00000283692;transcript_type=lncRNA;transcript_name=ENST00000637564;level=2;transcript_support_level=5;havana_gene=OTTHUMG00000191795.2;havana_transcript=OTTHUMT00000490104.1
# ignored: chrX	HAVANA	transcript	137573969	137981763	.	+	.	ID=ENST00000636095.1;Parent=ENSG00000283692.2;gene_id=ENSG00000283692.2;transcript_id=ENST00000636095.1;gene_type=lncRNA;gene_name=ENSG00000283692;transcript_type=lncRNA;transcript_name=ENST00000636095;level=2;transcript_support_level=5;tag=Ensembl_canonical;havana_gene=OTTHUMG00000191795.2;havana_transcript=OTTHUMT00000490105.1
# ignored: chrX	HAVANA	transcript	137573993	137981780	.	+	.	ID=ENST00000668975.1;Parent=ENSG00000283692.2;gene_id=ENSG00000283692.2;transcript_id=ENST00000668975.1;gene_type=lncRNA;gene_name=ENSG00000283692;transcript_type=lncRNA;transcript_name=ENST00000668975;level=2;tag=TAGENE;havana_gene=OTTHUMG00000191795.2;havana_transcript=OTTHUMT00000523169.1
gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-204;exon_number=7;exon_id=ENSE00003765119.2;level=2;protein_id=ENSP00000396198.2;transcript_support_level=2;hgnc_id=HGNC:3670;tag=basic,appris_alternative_1,CCDS;ccdsid=CCDS55513.1;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000058536.2
# ignored: chrX	HAVANA	stop_codon	138632850	138632852	.	-	0	ID=stop_codon:ENST00000441825.8;Parent=transcript:ENST00000441825.8;gene_id=ENSG00000129682.16;transcript_id=ENST00000441825.8;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-205;exon_number=7;exon_id=ENSE00001173345.6;level=2;protein_id=ENSP00000409276.2;transcript_support_level=5;hgnc_id=HGNC:3670;tag=basic,CCDS;ccdsid=CCDS55511.1;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000491549.1
# ignored: chrX	HAVANA	stop_codon	138632850	138632852	.	-	0	ID=stop_codon:ENST00000626909.2;Parent=transcript:ENST00000626909.2;gene_id=ENSG00000129682.16;transcript_id=ENST00000626909.2;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-208;exon_number=6;exon_id=ENSE00003763861.1;level=2;protein_id=ENSP00000487411.1;transcript_support_level=2;hgnc_id=HGNC:3670;tag=basic,appris_alternative_1,CCDS;ccdsid=CCDS55512.1;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000483253.1
# ignored: chrX	HAVANA	transcript	138635486	138990567	.	-	.	ID=ENST00000455663.5;Parent=ENSG00000129682.16;gene_id=ENSG00000129682.16;transcript_id=ENST00000455663.5;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-207;level=2;protein_id=ENSP00000406916.1;transcript_support_level=3;hgnc_id=HGNC:3670;tag=mRNA_end_NF,cds_end_NF;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000058538.2
# ignored: chrX	ENSEMBL	gene	138667711	138667793	.	-	.	ID=ENSG00000207800.3;gene_id=ENSG00000207800.3;gene_type=miRNA;gene_name=MIR504;level=3;hgnc_id=HGNC:32139
# ignored: chrX	ENSEMBL	transcript	138667711	138667793	.	-	.	ID=ENST00000385065.3;Parent=ENSG00000207800.3;gene_id=ENSG00000207800.3;transcript_id=ENST00000385065.3;gene_type=miRNA;gene_name=MIR504;transcript_type=miRNA;transcript_name=MIR504-201;level=3;transcript_support_level=NA;hgnc_id=HGNC:32139;tag=basic,Ensembl_canonical
# ignored: chrX	HAVANA	transcript	138708852	139222777	.	-	.	ID=ENST00000448673.1;Parent=ENSG00000129682.16;gene_id=ENSG00000129682.16;transcript_id=ENST00000448673.1;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-206;level=2;protein_id=ENSP00000411999.1;transcript_support_level=5;hgnc_id=HGNC:3670;tag=mRNA_end_NF,cds_end_NF;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000058537.2
# ignored: chrX	HAVANA	start_codon	138711001	138711003	.	-	0	ID=start_codon:ENST00000315930.11;Parent=transcript:ENST00000315930.11;gene_id=ENSG00000129682.16;transcript_id=ENST00000315930.11;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-202;exon_number=1;exon_id=ENSE00001124987.8;level=2;protein_id=ENSP00000322390.6;transcript_support_level=1;hgnc_id=HGNC:3670;tag=3_standard_supported_extension,basic,Ensembl_canonical,MANE_Select,appris_principal_4,CCDS;ccdsid=CCDS14665.1;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000
gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-205;exon_number=3;exon_id=ENSE00003518828.1;level=2;protein_id=ENSP00000409276.2;transcript_support_level=5;hgnc_id=HGNC:3670;tag=basic,CCDS;ccdsid=CCDS55511.1;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000491549.1
# ignored: chrX	HAVANA	start_codon	138985082	138985084	.	-	0	ID=start_codon:ENST00000455663.5;Parent=transcript:ENST00000455663.5;gene_id=ENSG00000129682.16;transcript_id=ENST00000455663.5;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-207;exon_number=2;exon_id=ENSE00001803242.1;level=2;protein_id=ENSP00000406916.1;transcript_support_level=3;hgnc_id=HGNC:3670;tag=mRNA_end_NF,cds_end_NF;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000058538.2
# ignored: chrX	HAVANA	start_codon	139204105	139204107	.	-	0	ID=start_codon:ENST00000436198.6;Parent=transcript:ENST00000436198.6;gene_id=ENSG00000129682.16;transcript_id=ENST00000436198.6;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-204;exon_number=2;exon_id=ENSE00001661708.1;level=2;protein_id=ENSP00000396198.2;transcript_support_level=2;hgnc_id=HGNC:3670;tag=basic,appris_alternative_1,CCDS;ccdsid=CCDS55513.1;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000058536.2
# ignored: chrX	HAVANA	start_codon	139204105	139204107	.	-	0	ID=start_codon:ENST00000448673.1;Parent=transcript:ENST00000448673.1;gene_id=ENSG00000129682.16;transcript_id=ENST00000448673.1;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-206;exon_number=2;exon_id=ENSE00001661708.1;level=2;protein_id=ENSP00000411999.1;transcript_support_level=5;hgnc_id=HGNC:3670;tag=mRNA_end_NF,cds_end_NF;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000058537.2
# ignored: chrX	HAVANA	start_codon	139204105	139204107	.	-	0	ID=start_codon:ENST00000626909.2;Parent=transcript:ENST00000626909.2;gene_id=ENSG00000129682.16;transcript_id=ENST00000626909.2;gene_type=protein_coding;gene_name=FGF13;transcript_type=protein_coding;transcript_name=FGF13-208;exon_number=2;exon_id=ENSE00001661708.1;level=2;protein_id=ENSP00000487411.1;transcript_support_level=2;hgnc_id=HGNC:3670;tag=basic,appris_alternative_1,CCDS;ccdsid=CCDS55512.1;havana_gene=OTTHUMG00000022532.8;havana_transcript=OTTHUMT00000483253.1
# ignored: chrX	HAVANA	gene	139362040	139362382	.	+	.	ID=ENSG00000173954.8;gene_id=ENSG00000173954.8;gene_type=processed_pseudogene;gene_name=SNURFL;level=1;hgnc_id=HGNC:29543;tag=pseudo_consens;havana_gene=OTTHUMG00000022534.1
# ignored: chrX	HAVANA	transcript	139362040	139362382	.	+	.	ID=ENST00000309296.5;Parent=ENSG00000173954.8;gene_id=ENSG00000173954.8;transcript_id=ENST00000309296.5;gene_type=processed_pseudogene;gene_name=SNURFL;transcript_type=processed_pseudogene;transcript_name=SNURFL-201;level=1;transcript_support_level=NA;hgnc_id=HGNC:29543;ont=PGO:0000004;tag=pseudo_consens,basic,Ensembl_canonical;havana_gene=OTTHUMG00000022534.1;havana_transcript=OTTHUMT00000058554.1
# ignored: chrX	HAVANA	gene	139446891	139447676	.	+	.	ID=ENSG00000232549.1;gene_id=ENSG00000232549.1;gene_type=processed_pseudogene;gene_name=SRD5A1P1;level=1;hgnc_id=HGNC:11286;tag=pseudo_consens;havana_gene=OTTHUMG00000022684.1
# ignored: chrX	HAVANA	transcript	139446891	139447676	.	+	.	ID=ENST00000442297.1;Parent=ENSG00000232549.1;gene_id=ENSG00000232549.1;transcript_id=ENST00000442297.1;gene_type=processed_pseudogene;gene_name=SRD5A1P1;transcript_type=processed_pseudogene;transcript_name=SRD5A1P1-201;level=1;transcript_support_level=NA;hgnc_id=HGNC:11286;ont=PGO:0000004;tag=pseudo_consens,basic,Ensembl_canonical;havana_gene=OTTHUMG00000022684.1;havana_transcript=OTTHUMT00000058852.1
# ignored: chrX	HAVANA	gene	139530739	139563459	.	+	.	ID=ENSG00000101981.12;gene_id=ENSG00000101981.12;gene_type=protein_coding;gene_name=F9;level=2;hgnc_id=HGNC:3551;havana_gene=OTTHUMG00000022536.4
# ignored: chrX	HAVANA	transcript	139530739	139563459	.	+	.	ID=ENST00000218099.7;Parent=ENSG00000101981.12;gene_id=ENSG00000101981.12;transcript_id=ENST00000218099.7;gene_type=protein_coding;gene_name=F9;transcript_type=protein_coding;transcript_name=F9-201;level=2;protein_id=ENSP00000218099.2;transcript_support_level=1;hgnc_id=HGNC:3551;tag=basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS14666.1;havana_gene=OTTHUMG00000022536.4;havana_transcript=OTTHUMT00000058557.2
# ignored: chrX	HAVANA	transcript	139530758	139548392	.	+	.	ID=ENST00000479617.2;Parent=ENSG00000101981.12;gene_id=ENSG00000101981.12;transcript_id=ENST00000479617.2;gene_type=protein_coding;gene_name=F9;transcript_type=protein_coding_CDS_not_defined;transcript_name=F9-203;level=2;transcript_support_level=5;hgnc_id=HGNC:3551;tag=non_canonical_TEC;havana_gene=OTTHUMG00000022536.4;havana_transcript=OTTHUMT00000058558.2
# ignored: chrX	ENSEMBL	start_codon	139530765	139530767	.	+	0	ID=start_codon:ENST00000394090.2;Parent=transcript:ENST00000394090.2;gene_id=ENSG00000101981.12;transcript_id=ENST00000394090.2;gene_type=protein_coding;gene_name=F9;transcript_type=protein_coding;transcript_name=F9-202;exon_number=1;exon_id=ENSE00002311612.1;level=3;protein_id=ENSP00000377650.2;transcript_support_level=1;hgnc_id=HGNC:3551;tag=basic,CCDS;ccdsid=CCDS83495.1;havana_gene=OTTHUMG00000022536.4
# ignored: chrX	ENSEMBL	transcript	139530765	139562071	.	+	.	ID=ENST00000394090.2;Parent=ENSG00000101981.12;gene_id=ENSG00000101981.12;transcript_id=ENST00000394090.2;gene_type=protein_coding;gene_name=F9;transcript_type=protein_coding;transcript_name=F9-202;level=3;protein_id=ENSP00000377650.2;transcript_support_level=1;hgnc_id=HGNC:3551;tag=basic,CCDS;ccdsid=CCDS83495.1;havana_gene=OTTHUMG00000022536.4
# ignored: chrX	HAVANA	start_codon	139530765	139530767	.	+	0	ID=start_codon:ENST00000218099.7;Parent=transcript:ENST00000218099.7;gene_id=ENSG00000101981.12;transcript_id=ENST00000218099.7;gene_type=protein_coding;gene_name=F9;transcript_type=protein_coding;transcript_name=F9-201;exon_number=1;exon_id=ENSE00003674048.2;level=2;protein_id=ENSP00000218099.2;transcript_support_level=1;hgnc_id=HGNC:3551;tag=basic,Ensembl_canonical,MANE_Select,appris_principal_1,CCDS;ccdsid=CCDS
gene_type=protein_coding;gene_name=MCF2;transcript_type=protein_coding;transcript_name=MCF2-201;exon_number=26;exon_id=ENSE00001872755.1;level=2;protein_id=ENSP00000342204.6;transcript_support_level=1;hgnc_id=HGNC:6940;tag=basic,CCDS;ccdsid=CCDS55516.1;havana_gene=OTTHUMG00000022537.6;havana_transcript=OTTHUMT00000058562.2
# ignored: chrX	HAVANA	stop_codon	139582471	139582473	.	-	0	ID=stop_codon:ENST00000370576.9;Parent=transcript:ENST00000370576.9;gene_id=ENSG00000101977.22;transcript_id=ENST00000370576.9;gene_type=protein_coding;gene_name=MCF2;transcript_type=protein_coding;transcript_name=MCF2-203;exon_number=25;exon_id=ENSE00001796761.2;level=2;protein_id=ENSP00000359608.4;transcript_support_level=1;hgnc_id=HGNC:6940;tag=basic,CCDS;ccdsid=CCDS14667.1;havana_gene=OTTHUMG00000022537.6;havana_transcript=OTTHUMT00000058560.2
# ...
# ignored: chrY	HAVANA	stop_codon	57128469	57128471	.	+	0	ID=stop_codon:ENST00000711260.1;Parent=transcript:ENST00000711260.1;gene_id=ENSG00000292366.1;transcript_id=ENST00000711260.1;gene_type=protein_coding;gene_name=VAMP7;transcript_type=protein_coding;transcript_name=VAMP7-207;exon_number=8;exon_id=ENSE00004015094.1;level=2;protein_id=ENSP00000518622.1;transcript_support_level=1;hgnc_id=HGNC:11486;tag=basic,appris_principal_1;havana_gene=OTTHUMG00000022679.3;havana_transcript=OTTHUMT00000058843.2
# ignored: chrY	HAVANA	stop_codon	57128469	57128471	.	+	0	ID=stop_codon:ENST00000711265.1;Parent=transcript:ENST00000711265.1;gene_id=ENSG00000292366.1;transcript_id=ENST00000711265.1;gene_type=protein_coding;gene_name=VAMP7;transcript_type=protein_coding;transcript_name=VAMP7-212;exon_number=7;exon_id=ENSE00004015114.1;level=2;protein_id=ENSP00000518619.1;transcript_support_level=1;hgnc_id=HGNC:11486;tag=basic;havana_gene=OTTHUMG00000022679.3;havana_transcript=OTTHUMT00000058847.2
# ignored: chrY	HAVANA	stop_codon	57128657	57128659	.	+	0	ID=stop_codon:ENST00000711264.1;Parent=transcript:ENST00000711264.1;gene_id=ENSG00000292366.1;transcript_id=ENST00000711264.1;gene_type=protein_coding;gene_name=VAMP7;transcript_type=protein_coding;transcript_name=VAMP7-211;exon_number=7;exon_id=ENSE00004015111.1;level=2;protein_id=ENSP00000518620.1;transcript_support_level=1;hgnc_id=HGNC:11486;tag=basic,Ensembl_canonical;havana_gene=OTTHUMG00000022679.3;havana_transcript=OTTHUMT00000058842.1
# ignored: chrY	HAVANA	gene	57165512	57165845	.	-	.	ID=ENSG00000292367.1;gene_id=ENSG00000292367.1;gene_type=processed_pseudogene;gene_name=ELOCP24;level=2;hgnc_id=HGNC:38160;havana_gene=OTTHUMG00000040493.1
# ignored: chrY	HAVANA	transcript	57165512	57165845	.	-	.	ID=ENST00000711266.1;Parent=ENSG00000292367.1;gene_id=ENSG00000292367.1;transcript_id=ENST00000711266.1;gene_type=processed_pseudogene;gene_name=ELOCP24;transcript_type=processed_pseudogene;transcript_name=ELOCP24-202;level=2;transcript_support_level=NA;hgnc_id=HGNC:38160;ont=PGO:0000004;tag=basic,Ensembl_canonical;havana_gene=OTTHUMG00000040493.1;havana_transcript=OTTHUMT00000097437.1
# ignored: chrY	HAVANA	gene	57171890	57172769	.	-	.	ID=ENSG00000292368.1;gene_id=ENSG00000292368.1;gene_type=processed_pseudogene;gene_name=TRPC6P1;level=2;hgnc_id=HGNC:23270;havana_gene=OTTHUMG00000022681.1
# ignored: chrY	HAVANA	transcript	57171890	57172769	.	-	.	ID=ENST00000711267.1;Parent=ENSG00000292368.1;gene_id=ENSG00000292368.1;transcript_id=ENST00000711267.1;gene_type=processed_pseudogene;gene_name=TRPC6P1;transcript_type=processed_pseudogene;transcript_name=TRPC6P1-202;level=2;transcript_support_level=NA;hgnc_id=HGNC:23270;ont=PGO:0000004;tag=basic,Ensembl_canonical;havana_gene=OTTHUMG00000022681.1;havana_transcript=OTTHUMT00000058849.1
# ignored: chrY	HAVANA	gene	57184216	57197337	.	+	.	ID=ENSG00000292373.1;gene_id=ENSG00000292373.1;gene_type=protein_coding;gene_name=IL9R;level=2;hgnc_id=HGNC:6030;tag=overlapping_locus;havana_gene=OTTHUMG00000022720.1
# ignored: chrY	HAVANA	transcript	57184216	57197337	.	+	.	ID=ENST00000711286.1;Parent=ENSG00000292373.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711286.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding;transcript_name=IL9R-205;level=2;protein_id=ENSP00000518617.1;transcript_support_level=1;hgnc_id=HGNC:6030;tag=basic,Ensembl_canonical,appris_principal_1;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058981.1
# ignored: chrY	HAVANA	transcript	57184226	57197337	.	+	.	ID=ENST00000711287.1;Parent=ENSG00000292373.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711287.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding;transcript_name=IL9R-206;level=2;protein_id=ENSP00000518616.1;transcript_support_level=1;hgnc_id=HGNC:6030;tag=basic;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058980.1
# ignored: chrY	HAVANA	transcript	57184254	57189490	.	+	.	ID=ENST00000711288.1;Parent=ENSG00000292373.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711288.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding_CDS_not_defined;transcript_name=IL9R-207;level=2;transcript_support_level=1;hgnc_id=HGNC:6030;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058982.1
# ignored: chrY	HAVANA	start_codon	57184264	57184266	.	+	0	ID=start_codon:ENST00000711287.1;Parent=transcript:ENST00000711287.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711287.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding;transcript_name=IL9R-206;exon_number=1;exon_id=ENSE00004015184.1;level=2;protein_id=ENSP00000518616.1;transcript_support_level=1;hgnc_id=HGNC:6030;tag=basic;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058980.1
# ignored: chrY	HAVANA	start_codon	57184280	57184282	.	+	0	ID=start_codon:ENST00000711286.1;Parent=transcript:ENST00000711286.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711286.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding;transcript_name=IL9R-205;exon_number=1;exon_id=ENSE00004015175.1;level=2;protein_id=ENSP00000518617.1;transcript_support_level=1;hgnc_id=HGNC:6030;tag=basic,Ensembl_canonical,appris_principal_1;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058981.1
# ignored: chrY	HAVANA	gene	57190738	57208756	.	+	.	ID=ENSG00000292369.1;gene_id=ENSG00000292369.1;gene_type=lncRNA;gene_name=ENSG00000292369;level=2;tag=overlapping_locus;havana_gene=OTTHUMG00000184987.2
# ignored: chrY	HAVANA	transcript	57190738	57208756	.	+	.	ID=ENST00000711268.1;Parent=ENSG00000292369.1;gene_id=ENSG00000292369.1;transcript_id=ENST00000711268.1;gene_type=lncRNA;gene_name=ENSG00000292369;transcript_type=retained_intron;transcript_name=ENST00000711268;level=2;transcript_support_level=5;tag=basic,Ensembl_canonical,readthrough_transcript;havana_gene=OTTHUMG00000184987.2;havana_transcript=OTTHUMT00000058983.2
# ignored: chrY	HAVANA	transcript	57192634	57194566	.	+	.	ID=ENST00000711289.1;Parent=ENSG00000292373.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711289.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding_CDS_not_defined;transcript_name=IL9R-208;level=2;transcript_support_level=2;hgnc_id=HGNC:6030;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058984.1
# ignored: chrY	HAVANA	stop_codon	57196370	57196372	.	+	0	ID=stop_codon:ENST00000711287.1;Parent=transcript:ENST00000711287.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711287.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding;transcript_name=IL9R-206;exon_number=9;exon_id=ENSE00004015189.1;level=2;protein_id=ENSP00000518616.1;transcript_support_level=1;hgnc_id=HGNC:6030;tag=basic;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058980.1
# ignored: chrY	HAVANA	stop_codon	57196927	57196929	.	+	0	ID=stop_codon:ENST00000711286.1;Parent=transcript:ENST00000711286.1;gene_id=ENSG00000292373.1;transcript_id=ENST00000711286.1;gene_type=protein_coding;gene_name=IL9R;transcript_type=protein_coding;transcript_name=IL9R-205;exon_number=9;exon_id=ENSE00004015183.1;level=2;protein_id=ENSP00000518617.1;transcript_support_level=1;hgnc_id=HGNC:6030;tag=basic,Ensembl_canonical,appris_principal_1;havana_gene=OTTHUMG00000022720.1;havana_transcript=OTTHUMT00000058981.1
# ignored: chrY	HAVANA	gene	57201143	57203357	.	-	.	ID=ENSG00000292370.1;gene_id=ENSG00000292370.1;gene_type=lncRNA;gene_name=WASIR1;level=2;hgnc_id=HGNC:38513;havana_gene=OTTHUMG00000022676.3
hgnc_id=HGNC:31685;havana_gene=OTTHUMG00000022677.5;havana_transcript=OTTHUMT00000058825.1
# ignored: chrY	HAVANA	transcript	57209306	57210051	.	+	.	ID=ENST00000711282.1;Parent=ENSG00000292372.1;gene_id=ENSG00000292372.1;transcript_id=ENST00000711282.1;gene_type=protein_coding;gene_name=WASH6P;transcript_type=retained_intron;transcript_name=WASH6P-227;level=2;transcript_support_level=1;hgnc_id=HGNC:31685;havana_gene=OTTHUMG00000022677.5;havana_transcript=OTTHUMT00000058833.1
# ignored: chrY	HAVANA	transcript	57209887	57212186	.	+	.	ID=ENST00000711283.1;Parent=ENSG00000292372.1;gene_id=ENSG00000292372.1;transcript_id=ENST00000711283.1;gene_type=protein_coding;gene_name=WASH6P;transcript_type=retained_intron;transcript_name=WASH6P-228;level=2;transcript_support_level=2;hgnc_id=HGNC:31685;havana_gene=OTTHUMG00000022677.5;havana_transcript=OTTHUMT00000058827.1
# ignored: chrY	HAVANA	transcript	57210344	57212074	.	+	.	ID=ENST00000711284.1;Parent=ENSG00000292372.1;gene_id=ENSG00000292372.1;transcript_id=ENST00000711284.1;gene_type=protein_coding;gene_name=WASH6P;transcript_type=retained_intron;transcript_name=WASH6P-229;level=2;transcript_support_level=1;hgnc_id=HGNC:31685;havana_gene=OTTHUMG00000022677.5;havana_transcript=OTTHUMT00000058834.1
# ignored: chrY	HAVANA	transcript	57210591	57212074	.	+	.	ID=ENST00000711285.1;Parent=ENSG00000292372.1;gene_id=ENSG00000292372.1;transcript_id=ENST00000711285.1;gene_type=protein_coding;gene_name=WASH6P;transcript_type=protein_coding_CDS_not_defined;transcript_name=WASH6P-230;level=2;transcript_support_level=2;hgnc_id=HGNC:31685;havana_gene=OTTHUMG00000022677.5;havana_transcript=OTTHUMT00000058835.1
# ignored: chrY	HAVANA	stop_codon	57211892	57211894	.	+	0	ID=stop_codon:ENST00000711272.1;Parent=transcript:ENST00000711272.1;gene_id=ENSG00000292372.1;transcript_id=ENST00000711272.1;gene_type=protein_coding;gene_name=WASH6P;transcript_type=protein_coding;transcript_name=WASH6P-217;exon_number=10;exon_id=ENSE00004015142.1;level=2;protein_id=ENSP00000518618.1;transcript_support_level=NA;hgnc_id=HGNC:31685;tag=basic,Ensembl_canonical,appris_principal_1;havana_gene=OTTHUMG00000022677.5
# ignored: chrY	HAVANA	gene	57212184	57214397	.	-	.	ID=ENSG00000292371.1;gene_id=ENSG00000292371.1;gene_type=unprocessed_pseudogene;gene_name=DDX11L16;level=2;hgnc_id=HGNC:37115;havana_gene=OTTHUMG00000022678.1
# ignored: chrY	HAVANA	transcript	57212184	57214397	.	-	.	ID=ENST00000711270.1;Parent=ENSG00000292371.1;gene_id=ENSG00000292371.1;transcript_id=ENST00000711270.1;gene_type=unprocessed_pseudogene;gene_name=DDX11L16;transcript_type=unprocessed_pseudogene;transcript_name=DDX11L16-207;level=2;transcript_support_level=NA;hgnc_id=HGNC:37115;ont=PGO:0000005;tag=basic,Ensembl_canonical;havana_gene=OTTHUMG00000022678.1;havana_transcript=OTTHUMT00000058841.1
# Indexed 0 transcripts, 0 exons, 0 CDSs, 0 UTRs
# Calling...

# %%
# !bcftools query -f '%CHROM\t%POS\t%REF\t%ALT\t[%INFO/BCSQ]\n' /content/drive/MyDrive/Cancer_WES_Project/vcf_files/SRR1952986_annotated.vcf > /content/coding_variants.tsv

# %%
# !echo -e "CHROM\tPOS\tREF\tALT\tBCSQ" | cat - /content/coding_variants.tsv > /content/coding_variants_with_header.tsv

# %%
# !head /content/coding_variants.tsv
# Out:
# chr1	2488173	T	G	.
# chr1	3703383	T	C	.
# chr1	3852235	A	G	.
# chr1	4914953	C	G	.
# chr1	5707004	T	A	.
# chr1	7416874	C	T	.
# chr1	7417056	A	G	.
# chr1	7417170	G	T	.
# chr1	7777109	C	G	.
# chr1	8309999	A	G	.

# %%
# !tr '\t' ',' < /content/coding_variants_with_header.tsv > /content/coding_variants.csv

# %%
from google.colab import files
files.download('/content/coding_variants.csv')
